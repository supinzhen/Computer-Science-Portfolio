# %%
import pandas as pd

# %%
data_base = pd.read_csv('Bank_Customer.csv') #讀入資料庫

# %%
data_base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
data_base.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %% [markdown]
# # 資料處理

# %%
import numpy as np

# %%
feature_cols = ['credit_score','country','gender','age','tenure','balance','products_number','credit_card','active_member','estimated_salary']

# %%
data = data_base.loc[:, feature_cols]

# %%
data.head()
# Out:
#    credit_score country  gender  age  tenure    balance  products_number  \
# 0           619  France  Female   42       2       0.00                1
# 1           608   Spain  Female   41       1   83807.86                1
# 2           502  France  Female   42       8  159660.80                3
# 3           699  France  Female   39       1       0.00                2
# 4           850   Spain  Female   43       2  125510.82                1
#
#    credit_card  active_member  estimated_salary
# 0            1              1         101348.88
# 1            0              1         112542.58
# 2            1              0         113931.57
# 3            0              0          93826.63
# 4            1              1          79084.10

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   credit_score      10000 non-null  int64
#  1   country           10000 non-null  object
#  2   gender            10000 non-null  object
#  3   age               10000 non-null  int64
#  4   tenure            10000 non-null  int64
#  5   balance           10000 non-null  float64
#  6   products_number   10000 non-null  int64
#  7   credit_card       10000 non-null  int64
#  8   active_member     10000 non-null  int64
#  9   estimated_salary  10000 non-null  float64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 781.4+ KB

# %%
target = data_base.churn.values

# %%
target
# Out:
# array([1, 0, 1, ..., 1, 1, 0], dtype=int64)

# %%
data_country = data['country']
data_gender = data['gender']
for i in range(0,10000):
    if(data_country[i] == 'France'):
        data_country[i] = 0
    elif(data_country[i] == 'Germany'):
        data_country[i] = 1
    elif(data_country[i] == 'Spain'):
        data_country[i] = 2
    if(data_gender[i] == 'Male'):
        data_gender[i] = 0
    elif(data_gender[i] == 'Female'):
        data_gender[i] = 1
# Out:
# C:\Users\annie\AppData\Local\Temp\ipykernel_12000\2712572799.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_country[i] = 0
# C:\Users\annie\AppData\Local\Temp\ipykernel_12000\2712572799.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_gender[i] = 1
# C:\Users\annie\AppData\Local\Temp\ipykernel_12000\2712572799.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_country[i] = 2
# C:\Users\annie\AppData\Local\Temp\ipykernel_12000\2712572799.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_gender[i] = 0
# C:\Users\annie\AppData\Local\Temp\ipykernel_12000\2712572799.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_country[i] = 1

# %%
data.head()
# Out:
#    credit_score country gender  age  tenure    balance  products_number  \
# 0           619       0      1   42       2       0.00                1
# 1           608       2      1   41       1   83807.86                1
# 2           502       0      1   42       8  159660.80                3
# 3           699       0      1   39       1       0.00                2
# 4           850       2      1   43       2  125510.82                1
#
#    credit_card  active_member  estimated_salary
# 0            1              1         101348.88
# 1            0              1         112542.58
# 2            1              0         113931.57
# 3            0              0          93826.63
# 4            1              1          79084.10

# %%
data['country'] = data['country'].astype(int)
data['gender'] = data['gender'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   credit_score      10000 non-null  int64
#  1   country           10000 non-null  int32
#  2   gender            10000 non-null  int32
#  3   age               10000 non-null  int64
#  4   tenure            10000 non-null  int64
#  5   balance           10000 non-null  float64
#  6   products_number   10000 non-null  int64
#  7   credit_card       10000 non-null  int64
#  8   active_member     10000 non-null  int64
#  9   estimated_salary  10000 non-null  float64
# dtypes: float64(2), int32(2), int64(6)
# memory usage: 703.2 KB

# %% [markdown]
# # 訓練資料與測試資料

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

# %%
x_train,x_test,y_train,y_test = train_test_split(data,target,test_size=0.3,random_state = 42)

# %%
data.head()
# Out:
#    credit_score  country  gender  age  tenure    balance  products_number  \
# 0           619        0       1   42       2       0.00                1
# 1           608        2       1   41       1   83807.86                1
# 2           502        0       1   42       8  159660.80                3
# 3           699        0       1   39       1       0.00                2
# 4           850        2       1   43       2  125510.82                1
#
#    credit_card  active_member  estimated_salary
# 0            1              1         101348.88
# 1            0              1         112542.58
# 2            1              0         113931.57
# 3            0              0          93826.63
# 4            1              1          79084.10

# %%
x_train.shape
# Out:
# (7000, 10)

# %%
y_train.shape
# Out:
# (7000,)

# %%
x_test.shape
# Out:
# (3000, 10)

# %%
y_test.shape
# Out:
# (3000,)

# %% [markdown]
# # 建立決策樹

# %%
from sklearn import tree

# %%
ori_clf = tree.DecisionTreeClassifier(criterion = "entropy", class_weight="balanced")
ori_clf = ori_clf.fit(x_train,y_train)

# %%
tree.plot_tree(ori_clf)
# Out:
# [Text(0.5811783611240672, 0.9857142857142858, 'X[3] <= 39.5\nentropy = 1.0\nsamples = 7000\nvalue = [3500.0, 3500.0]'),
#  Text(0.3775144298041045, 0.9571428571428572, 'X[6] <= 2.5\nentropy = 0.883\nsamples = 4201\nvalue = [2381.918, 1026.153]'),
#  Text(0.2757751282649254, 0.9285714285714286, 'X[6] <= 1.5\nentropy = 0.841\nsamples = 4117\nvalue = [2368.668, 874.398]'),
#  Text(0.15057544309701493, 0.9, 'X[1] <= 0.5\nentropy = 0.962\nsamples = 2007\nvalue = [1087.795, 681.693]'),
#  Text(0.06753148320895522, 0.8714285714285714, 'X[5] <= 73493.691\nentropy = 0.864\nsamples = 1041\nvalue = [594.375, 238.472]'),
#  Text(0.01328125, 0.8428571428571429, 'X[4] <= 1.5\nentropy = 0.993\nsamples = 260\nvalue = [135.028, 110.805]'),
#  Text(0.006007462686567164, 0.8142857142857143, 'X[3] <= 36.5\nentropy = 0.707\nsamples = 34\nvalue = [20.191, 4.818]'),
#  Text(0.0036194029850746268, 0.7857142857142857, 'X[5] <= 26684.564\nentropy = 0.0\nsamples = 29\nvalue = [18.298, 0.0]'),
#  Text(0.002425373134328358, 0.7571428571428571, 'entropy = 0.0\nsamples = 21\nvalue = [13.25, 0.0]'),
#  Text(0.0048134328358208954, 0.7571428571428571, 'entropy = 0.0\nsamples = 8\nvalue = [5.048, 0.0]'),
#  Text(0.008395522388059701, 0.7857142857142857, 'X[5] <= 19672.414\nentropy = 0.858\nsamples = 5\nvalue = [1.893, 4.818]'),
#  Text(0.007201492537313433, 0.7571428571428571, 'X[9] <= 17534.26\nentropy = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.006007462686567164, 0.7285714285714285, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.008395522388059701, 0.7285714285714285, 'entropy = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.009589552238805971, 0.7571428571428571, 'entropy = -0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.020555037313432837, 0.8142857142857143, 'X[3] <= 22.5\nentropy = 0.999\nsamples = 226\nvalue = [114.837, 105.988]'),
#  Text(0.019361007462686566, 0.7857142857142857, 'entropy = 0.0\nsamples = 9\nvalue = [5.679, 0.0]'),
#  Text(0.021749067164179105, 0.7857142857142857, 'X[3] <= 26.5\nentropy = 1.0\nsamples = 217\nvalue = [109.158, 105.988]'),
#  Text(0.013171641791044776, 0.7571428571428571, 'X[9] <= 66593.92\nentropy = 0.814\nsamples = 16\nvalue = [5.679, 16.862]'),
#  Text(0.010783582089552239, 0.7285714285714285, 'X[4] <= 8.5\nentropy = 0.987\nsamples = 6\nvalue = [3.155, 2.409]'),
#  Text(0.009589552238805971, 0.7, 'entropy = -0.0\nsamples = 5\nvalue = [3.155, 0.0]'),
#  Text(0.011977611940298508, 0.7, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.015559701492537313, 0.7285714285714285, 'X[3] <= 25.5\nentropy = 0.606\nsamples = 10\nvalue = [2.524, 14.453]'),
#  Text(0.014365671641791044, 0.7, 'X[0] <= 573.0\nentropy = 0.825\nsamples = 7\nvalue = [2.524, 7.226]'),
#  Text(0.013171641791044776, 0.6714285714285714, 'entropy = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.015559701492537313, 0.6714285714285714, 'X[0] <= 726.0\nentropy = 0.606\nsamples = 5\nvalue = [1.262, 7.226]'),
#  Text(0.014365671641791044, 0.6428571428571429, 'X[3] <= 24.5\nentropy = 0.403\nsamples = 4\nvalue = [0.631, 7.226]'),
#  Text(0.013171641791044776, 0.6142857142857143, 'entropy = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.015559701492537313, 0.6142857142857143, 'entropy = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.016753731343283583, 0.6428571428571429, 'entropy = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.016753731343283583, 0.7, 'entropy = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.030326492537313433, 0.7571428571428571, 'X[3] <= 30.5\nentropy = 0.996\nsamples = 201\nvalue = [103.479, 89.126]'),
#  Text(0.023917910447761193, 0.7285714285714285, 'X[0] <= 529.0\nentropy = 0.627\nsamples = 43\nvalue = [25.87, 4.818]'),
#  Text(0.021529850746268658, 0.7, 'X[2] <= 0.5\nentropy = 0.858\nsamples = 5\nvalue = [1.893, 4.818]'),
#  Text(0.020335820895522386, 0.6714285714285714, 'X[8] <= 0.5\nentropy = 0.517\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.01914179104477612, 0.6428571428571429, 'entropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.021529850746268658, 0.6428571428571429, 'entropy = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.022723880597014925, 0.6714285714285714, 'entropy = -0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.026305970149253732, 0.7, 'X[7] <= 0.5\nentropy = 0.0\nsamples = 38\nvalue = [23.977, 0.0]'),
#  Text(0.02511194029850746, 0.6714285714285714, 'entropy = 0.0\nsamples = 11\nvalue = [6.941, 0.0]'),
#  Text(0.0275, 0.6714285714285714, 'entropy = 0.0\nsamples = 27\nvalue = [17.036, 0.0]'),
#  Text(0.03673507462686567, 0.7285714285714285, 'X[0] <= 474.0\nentropy = 0.999\nsamples = 158\nvalue = [77.61, 84.308]'),
#  Text(0.035541044776119406, 0.7, 'entropy = 0.0\nsamples = 9\nvalue = [5.679, 0.0]'),
#  Text(0.03792910447761194, 0.7, 'X[9] <= 170601.062\nentropy = 0.995\nsamples = 149\nvalue = [71.931, 84.308]'),
#  Text(0.029888059701492536, 0.6714285714285714, 'X[9] <= 148086.852\nentropy = 1.0\nsamples = 131\nvalue = [64.99, 67.447]'),
#  Text(0.028694029850746268, 0.6428571428571429, 'X[9] <= 121182.578\nentropy = 0.992\nsamples = 115\nvalue = [54.895, 67.447]'),
#  Text(0.021567164179104478, 0.6142857142857143, 'X[9] <= 79592.887\nentropy = 0.999\nsamples = 96\nvalue = [48.585, 45.767]'),
#  Text(0.015671641791044775, 0.5857142857142857, 'X[4] <= 9.5\nentropy = 0.984\nsamples = 65\nvalue = [30.287, 40.95]'),
#  Text(0.011044776119402985, 0.5571428571428572, 'X[9] <= 20298.45\nentropy = 0.996\nsamples = 60\nvalue = [29.025, 33.723]'),
#  Text(0.009850746268656717, 0.5285714285714286, 'entropy = 0.0\nsamples = 8\nvalue = [5.048, 0.0]'),
#  Text(0.012238805970149255, 0.5285714285714286, 'X[4] <= 8.5\nentropy = 0.979\nsamples = 52\nvalue = [23.977, 33.723]'),
#  Text(0.011044776119402985, 0.5, 'X[4] <= 5.5\nentropy = 0.959\nsamples = 47\nvalue = [20.822, 33.723]'),
#  Text(0.007761194029850746, 0.4714285714285714, 'X[4] <= 4.5\nentropy = 0.996\nsamples = 27\nvalue = [13.881, 12.044]'),
#  Text(0.004776119402985075, 0.44285714285714284, 'X[0] <= 610.0\nentropy = 0.928\nsamples = 15\nvalue = [6.31, 12.044]'),
#  Text(0.0023880597014925373, 0.4142857142857143, 'X[0] <= 516.0\nentropy = 0.644\nsamples = 7\nvalue = [1.893, 9.635]'),
#  Text(0.0011940298507462687, 0.38571428571428573, 'entropy = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.003582089552238806, 0.38571428571428573, 'X[0] <= 555.0\nentropy = 0.333\nsamples = 5\nvalue = [0.631, 9.635]'),
#  Text(0.0023880597014925373, 0.35714285714285715, 'X[7] <= 0.5\nentropy = 0.737\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.0011940298507462687, 0.32857142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.003582089552238806, 0.32857142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.004776119402985075, 0.35714285714285715, 'entropy = -0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.007164179104477612, 0.4142857142857143, 'X[9] <= 37094.629\nentropy = 0.937\nsamples = 8\nvalue = [4.417, 2.409]'),
#  Text(0.005970149253731343, 0.38571428571428573, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.00835820895522388, 0.38571428571428573, 'entropy = -0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  Text(0.010746268656716417, 0.44285714285714284, 'X[3] <= 33.5\nentropy = 0.0\nsamples = 12\nvalue = [7.572, 0.0]'),
#  Text(0.00955223880597015, 0.4142857142857143, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.011940298507462687, 0.4142857142857143, 'entropy = 0.0\nsamples = 11\nvalue = [6.941, 0.0]'),
#  Text(0.014328358208955224, 0.4714285714285714, 'X[0] <= 552.0\nentropy = 0.799\nsamples = 20\nvalue = [6.941, 21.679]'),
#  Text(0.013134328358208954, 0.44285714285714284, 'entropy = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.015522388059701492, 0.44285714285714284, 'X[0] <= 608.5\nentropy = 0.909\nsamples = 17\nvalue = [6.941, 14.453]'),
#  Text(0.014328358208955224, 0.4142857142857143, 'entropy = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.01671641791044776, 0.4142857142857143, 'X[9] <= 58250.641\nentropy = 0.825\nsamples = 14\nvalue = [5.048, 14.453]'),
#  Text(0.01373134328358209, 0.38571428571428573, 'X[3] <= 38.0\nentropy = 0.678\nsamples = 11\nvalue = [3.155, 14.453]'),
#  Text(0.011343283582089553, 0.35714285714285715, 'X[3] <= 32.0\nentropy = 0.517\nsamples = 9\nvalue = [1.893, 14.453]'),
#  Text(0.010149253731343283, 0.32857142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.01253731343283582, 0.32857142857142857, 'X[0] <= 805.0\nentropy = 0.403\nsamples = 8\nvalue = [1.262, 14.453]'),
#  Text(0.011343283582089553, 0.3, 'X[9] <= 24873.931\nentropy = 0.251\nsamples = 7\nvalue = [0.631, 14.453]'),
#  Text(0.010149253731343283, 0.2714285714285714, 'X[9] <= 21667.325\nentropy = 0.737\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.008955223880597015, 0.24285714285714285, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.011343283582089553, 0.24285714285714285, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.01253731343283582, 0.2714285714285714, 'entropy = 0.0\nsamples = 5\nvalue = [0.0, 12.044]'),
#  Text(0.01373134328358209, 0.3, 'entropy = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.016119402985074627, 0.35714285714285715, 'X[8] <= 0.5\nentropy = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.014925373134328358, 0.32857142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.017313432835820895, 0.32857142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.019701492537313434, 0.38571428571428573, 'X[0] <= 682.0\nentropy = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.018507462686567163, 0.35714285714285715, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.020895522388059702, 0.35714285714285715, 'entropy = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.013432835820895522, 0.5, 'entropy = -0.0\nsamples = 5\nvalue = [3.155, 0.0]'),
#  Text(0.020298507462686566, 0.5571428571428572, 'X[9] <= 64490.324\nentropy = 0.606\nsamples = 5\nvalue = [1.262, 7.226]'),
#  Text(0.0191044776119403, 0.5285714285714286, 'X[0] <= 579.5\nentropy = 0.403\nsamples = 4\nvalue = [0.631, 7.226]'),
#  Text(0.01791044776119403, 0.5, 'X[8] <= 0.5\nentropy = 0.737\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.01671641791044776, 0.4714285714285714, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.0191044776119403, 0.4714285714285714, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.020298507462686566, 0.5, 'entropy = -0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.021492537313432834, 0.5285714285714286, 'entropy = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.02746268656716418, 0.5857142857142857, 'X[9] <= 111332.754\nentropy = 0.738\nsamples = 31\nvalue = [18.298, 4.818]'),
#  Text(0.02507462686567164, 0.5571428571428572, 'X[7] <= 0.5\nentropy = 0.0\nsamples = 22\nvalue = [13.881, 0.0]'),
#  Text(0.023880597014925373, 0.5285714285714286, 'entropy = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.02626865671641791, 0.5285714285714286, 'entropy = 0.0\nsamples = 18\nvalue = [11.357, 0.0]'),
#  Text(0.029850746268656716, 0.5571428571428572, 'X[9] <= 115494.098\nentropy = 0.999\nsamples = 9\nvalue = [4.417, 4.818]'),
#  Text(0.028656716417910448, 0.5285714285714286, 'X[4] <= 9.5\nentropy = 0.517\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.02746268656716418, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.029850746268656716, 0.5, 'entropy = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.031044776119402984, 0.5285714285714286, 'entropy = 0.0\nsamples = 6\nvalue = [3.786, 0.0]'),
#  Text(0.03582089552238806, 0.6142857142857143, 'X[0] <= 587.5\nentropy = 0.77\nsamples = 19\nvalue = [6.31, 21.679]'),
#  Text(0.03462686567164179, 0.5857142857142857, 'entropy = 0.0\nsamples = 5\nvalue = [3.155, 0.0]'),
#  Text(0.037014925373134326, 0.5857142857142857, 'X[3] <= 38.5\nentropy = 0.549\nsamples = 14\nvalue = [3.155, 21.679]'),
#  Text(0.03462686567164179, 0.5571428571428572, 'X[4] <= 9.0\nentropy = 0.403\nsamples = 12\nvalue = [1.893, 21.679]'),
#  Text(0.03343283582089552, 0.5285714285714286, 'X[9] <= 132390.355\nentropy = 0.307\nsamples = 11\nvalue = [1.262, 21.679]'),
#  Text(0.032238805970149255, 0.5, 'X[9] <= 123701.094\nentropy = 0.606\nsamples = 5\nvalue = [1.262, 7.226]'),
#  Text(0.031044776119402984, 0.4714285714285714, 'entropy = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.03343283582089552, 0.4714285714285714, 'entropy = -0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.03462686567164179, 0.5, 'entropy = 0.0\nsamples = 6\nvalue = [0.0, 14.453]'),
#  Text(0.03582089552238806, 0.5285714285714286, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.03940298507462687, 0.5571428571428572, 'X[9] <= 142491.312\nentropy = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.0382089552238806, 0.5285714285714286, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.04059701492537313, 0.5285714285714286, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.031082089552238807, 0.6428571428571429, 'entropy = 0.0\nsamples = 16\nvalue = [10.096, 0.0]'),
#  Text(0.04597014925373134, 0.6714285714285714, 'X[9] <= 183265.359\nentropy = 0.871\nsamples = 18\nvalue = [6.941, 16.862]'),
#  Text(0.04298507462686567, 0.6428571428571429, 'X[9] <= 180781.812\nentropy = 0.452\nsamples = 7\nvalue = [1.262, 12.044]'),
#  Text(0.041791044776119404, 0.6142857142857143, 'X[9] <= 178967.844\nentropy = 0.737\nsamples = 4\nvalue = [1.262, 4.818]'),
#  Text(0.04059701492537313, 0.5857142857142857, 'entropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.04298507462686567, 0.5857142857142857, 'X[2] <= 0.5\nentropy = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.041791044776119404, 0.5571428571428572, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.04417910447761194, 0.5571428571428572, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.04417910447761194, 0.6142857142857143, 'entropy = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.04895522388059702, 0.6428571428571429, 'X[9] <= 188413.625\nentropy = 0.995\nsamples = 11\nvalue = [5.679, 4.818]'),
#  Text(0.046567164179104475, 0.6142857142857143, 'X[8] <= 0.5\nentropy = 0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  Text(0.04537313432835821, 0.5857142857142857, 'entropy = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.04776119402985075, 0.5857142857142857, 'entropy = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.051343283582089554, 0.6142857142857143, 'X[2] <= 0.5\nentropy = 0.737\nsamples = 4\nvalue = [1.262, 4.818]'),
#  Text(0.05014925373134328, 0.5857142857142857, 'X[9] <= 198162.508\nentropy = 0.517\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.04895522388059702, 0.5571428571428572, 'entropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.051343283582089554, 0.5571428571428572, 'entropy = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.05253731343283582, 0.5857142857142857, 'entropy = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.12178171641791045, 0.8428571428571429, 'X[5] <= 178072.172\nentropy = 0.756\nsamples = 781\nvalue = [459.347, 127.667]'),
#  Text(0.09968283582089552, 0.8142857142857143, 'X[9] <= 16687.935\nentropy = 0.696\nsamples = 754\nvalue = [448.621, 103.579]'),
#  Text(0.09848880597014925, 0.7857142857142857, 'entropy = 0.0\nsamples = 54\nvalue = [34.072, 0.0]'),
#  Text(0.1008768656716418, 0.7857142857142857, 'X[3] <= 35.5\nentropy = 0.722\nsamples = 700\nvalue = [414.548, 103.579]'),
#  Text(0.08567164179104478, 0.7571428571428571, 'X[9] <= 149480.711\nentropy = 0.645\nsamples = 489\nvalue = [293.402, 57.811]'),
#  Text(0.07582089552238806, 0.7285714285714285, 'X[9] <= 68459.793\nentropy = 0.553\nsamples = 350\nvalue = [212.637, 31.315]'),
#  Text(0.06925373134328358, 0.7, 'X[3] <= 33.5\nentropy = 0.726\nsamples = 161\nvalue = [95.277, 24.088]'),
#  Text(0.06805970149253732, 0.6714285714285714, 'X[8] <= 0.5\nentropy = 0.792\nsamples = 132\nvalue = [76.979, 24.088]'),
#  Text(0.06328358208955225, 0.6428571428571429, 'X[3] <= 26.5\nentropy = 0.929\nsamples = 66\nvalue = [36.596, 19.27]'),
#  Text(0.057313432835820896, 0.6142857142857143, 'X[0] <= 657.0\nentropy = 0.99\nsamples = 20\nvalue = [9.465, 12.044]'),
#  Text(0.05492537313432836, 0.5857142857142857, 'X[4] <= 0.5\nentropy = 0.0\nsamples = 11\nvalue = [6.941, 0.0]'),
#  Text(0.05373134328358209, 0.5571428571428572, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.056119402985074625, 0.5571428571428572, 'entropy = 0.0\nsamples = 10\nvalue = [6.31, 0.0]'),
#  Text(0.05970149253731343, 0.5857142857142857, 'X[0] <= 706.5\nentropy = 0.665\nsamples = 9\nvalue = [2.524, 12.044]'),
#  Text(0.05850746268656717, 0.5571428571428572, 'entropy = 0.0\nsamples = 4\nvalue = [0.0, 9.635]'),
#  Text(0.0608955223880597, 0.5571428571428572, 'X[5] <= 138760.406\nentropy = 1.0\nsamples = 5\nvalue = [2.524, 2.409]'),
#  Text(0.05970149253731343, 0.5285714285714286, 'entropy = -0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.06208955223880597, 0.5285714285714286, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.06925373134328358, 0.6142857142857143, 'X[0] <= 641.0\nentropy = 0.742\nsamples = 46\nvalue = [27.132, 7.226]'),
#  Text(0.06805970149253732, 0.5857142857142857, 'X[5] <= 153690.406\nentropy = 0.955\nsamples = 22\nvalue = [11.988, 7.226]'),
#  Text(0.06686567164179104, 0.5571428571428572, 'X[9] <= 58070.564\nentropy = 0.864\nsamples = 21\nvalue = [11.988, 4.818]'),
#  Text(0.06447761194029851, 0.5285714285714286, 'X[0] <= 528.5\nentropy = 0.0\nsamples = 13\nvalue = [8.203, 0.0]'),
#  Text(0.06328358208955225, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.06567164179104477, 0.5, 'entropy = 0.0\nsamples = 12\nvalue = [7.572, 0.0]'),
#  Text(0.06925373134328358, 0.5285714285714286, 'X[3] <= 31.5\nentropy = 0.99\nsamples = 8\nvalue = [3.786, 4.818]'),
#  Text(0.06805970149253732, 0.5, 'X[9] <= 63766.42\nentropy = 0.517\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.06686567164179104, 0.4714285714285714, 'X[9] <= 61289.709\nentropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.06567164179104477, 0.44285714285714284, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.06805970149253732, 0.44285714285714284, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.06925373134328358, 0.4714285714285714, 'entropy = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.07044776119402985, 0.5, 'entropy = -0.0\nsamples = 5\nvalue = [3.155, 0.0]'),
#  Text(0.06925373134328358, 0.5571428571428572, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.07044776119402985, 0.5857142857142857, 'entropy = -0.0\nsamples = 24\nvalue = [15.143, 0.0]'),
#  Text(0.07283582089552239, 0.6428571428571429, 'X[5] <= 123041.0\nentropy = 0.49\nsamples = 66\nvalue = [40.382, 4.818]'),
#  Text(0.07164179104477612, 0.6142857142857143, 'entropy = -0.0\nsamples = 43\nvalue = [27.132, 0.0]'),
#  Text(0.07402985074626865, 0.6142857142857143, 'X[5] <= 123986.895\nentropy = 0.837\nsamples = 23\nvalue = [13.25, 4.818]'),
#  Text(0.07283582089552239, 0.5857142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.07522388059701493, 0.5857142857142857, 'X[3] <= 31.5\nentropy = 0.619\nsamples = 22\nvalue = [13.25, 2.409]'),
#  Text(0.07402985074626865, 0.5571428571428572, 'entropy = 0.0\nsamples = 18\nvalue = [11.357, 0.0]'),
#  Text(0.0764179104477612, 0.5571428571428572, 'X[3] <= 32.5\nentropy = 0.99\nsamples = 4\nvalue = [1.893, 2.409]'),
#  Text(0.07522388059701493, 0.5285714285714286, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.07761194029850746, 0.5285714285714286, 'entropy = -0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.07044776119402985, 0.6714285714285714, 'entropy = 0.0\nsamples = 29\nvalue = [18.298, 0.0]'),
#  Text(0.08238805970149254, 0.7, 'X[3] <= 32.5\nentropy = 0.319\nsamples = 189\nvalue = [117.361, 7.226]'),
#  Text(0.08, 0.6714285714285714, 'X[2] <= 0.5\nentropy = 0.0\nsamples = 124\nvalue = [78.24, 0.0]'),
#  Text(0.07880597014925374, 0.6428571428571429, 'entropy = 0.0\nsamples = 74\nvalue = [46.692, 0.0]'),
#  Text(0.08119402985074627, 0.6428571428571429, 'entropy = 0.0\nsamples = 50\nvalue = [31.549, 0.0]'),
#  Text(0.08477611940298507, 0.6714285714285714, 'X[5] <= 110029.801\nentropy = 0.624\nsamples = 65\nvalue = [39.12, 7.226]'),
#  Text(0.08358208955223881, 0.6428571428571429, 'X[5] <= 108231.746\nentropy = 0.917\nsamples = 26\nvalue = [14.512, 7.226]'),
#  Text(0.08119402985074627, 0.6142857142857143, 'X[5] <= 82991.57\nentropy = 0.59\nsamples = 24\nvalue = [14.512, 2.409]'),
#  Text(0.08, 0.5857142857142857, 'X[9] <= 109407.457\nentropy = 0.928\nsamples = 3\nvalue = [1.262, 2.409]'),
#  Text(0.07880597014925374, 0.5571428571428572, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.08119402985074627, 0.5571428571428572, 'entropy = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.08238805970149254, 0.5857142857142857, 'entropy = 0.0\nsamples = 21\nvalue = [13.25, 0.0]'),
#  Text(0.08597014925373134, 0.6142857142857143, 'X[2] <= 0.5\nentropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.08477611940298507, 0.5857142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.08716417910447762, 0.5857142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.08597014925373134, 0.6428571428571429, 'entropy = -0.0\nsamples = 39\nvalue = [24.608, 0.0]'),
#  Text(0.0955223880597015, 0.7285714285714285, 'X[9] <= 155243.102\nentropy = 0.807\nsamples = 139\nvalue = [80.764, 26.497]'),
#  Text(0.08955223880597014, 0.7, 'X[2] <= 0.5\nentropy = 0.962\nsamples = 17\nvalue = [7.572, 12.044]'),
#  Text(0.08835820895522388, 0.6714285714285714, 'entropy = 0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  Text(0.09074626865671642, 0.6714285714285714, 'X[8] <= 0.5\nentropy = 0.737\nsamples = 10\nvalue = [3.155, 12.044]'),
#  Text(0.08955223880597014, 0.6428571428571429, 'entropy = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.09194029850746269, 0.6428571428571429, 'X[5] <= 130636.273\nentropy = 0.968\nsamples = 7\nvalue = [3.155, 4.818]'),
#  Text(0.09074626865671642, 0.6142857142857143, 'X[9] <= 152853.484\nentropy = 0.517\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.08955223880597014, 0.5857142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.09194029850746269, 0.5857142857142857, 'entropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.09313432835820895, 0.6142857142857143, 'entropy = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.10149253731343283, 0.7, 'X[3] <= 33.5\nentropy = 0.646\nsamples = 122\nvalue = [73.193, 14.453]'),
#  Text(0.10029850746268656, 0.6714285714285714, 'X[3] <= 31.5\nentropy = 0.731\nsamples = 95\nvalue = [56.156, 14.453]'),
#  Text(0.09671641791044776, 0.6428571428571429, 'X[9] <= 164459.984\nentropy = 0.464\nsamples = 72\nvalue = [44.168, 4.818]'),
#  Text(0.0955223880597015, 0.6142857142857143, 'X[9] <= 162972.203\nentropy = 0.908\nsamples = 18\nvalue = [10.096, 4.818]'),
#  Text(0.09432835820895523, 0.5857142857142857, 'entropy = 0.0\nsamples = 14\nvalue = [8.834, 0.0]'),
#  Text(0.09671641791044776, 0.5857142857142857, 'X[5] <= 119943.195\nentropy = 0.737\nsamples = 4\nvalue = [1.262, 4.818]'),
#  Text(0.0955223880597015, 0.5571428571428572, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.09791044776119404, 0.5571428571428572, 'X[8] <= 0.5\nentropy = 0.517\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.09671641791044776, 0.5285714285714286, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.0991044776119403, 0.5285714285714286, 'X[4] <= 6.5\nentropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.09791044776119404, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.10029850746268656, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.09791044776119404, 0.6142857142857143, 'entropy = -0.0\nsamples = 54\nvalue = [34.072, 0.0]'),
#  Text(0.10388059701492537, 0.6428571428571429, 'X[9] <= 187911.906\nentropy = 0.991\nsamples = 23\nvalue = [11.988, 9.635]'),
#  Text(0.10268656716417911, 0.6142857142857143, 'entropy = 0.0\nsamples = 11\nvalue = [6.941, 0.0]'),
#  Text(0.10507462686567164, 0.6142857142857143, 'X[9] <= 197918.445\nentropy = 0.928\nsamples = 12\nvalue = [5.048, 9.635]'),
#  Text(0.10388059701492537, 0.5857142857142857, 'X[4] <= 7.5\nentropy = 0.737\nsamples = 8\nvalue = [2.524, 9.635]'),
#  Text(0.10268656716417911, 0.5571428571428572, 'entropy = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.10507462686567164, 0.5571428571428572, 'X[9] <= 190340.227\nentropy = 1.0\nsamples = 5\nvalue = [2.524, 2.409]'),
#  Text(0.10388059701492537, 0.5285714285714286, 'X[4] <= 9.5\nentropy = 0.737\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.10268656716417911, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.10507462686567164, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.10626865671641791, 0.5285714285714286, 'entropy = -0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.10626865671641791, 0.5857142857142857, 'entropy = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.10268656716417911, 0.6714285714285714, 'entropy = 0.0\nsamples = 27\nvalue = [17.036, 0.0]'),
#  Text(0.11608208955223881, 0.7571428571428571, 'X[9] <= 22130.325\nentropy = 0.847\nsamples = 211\nvalue = [121.147, 45.767]'),
#  Text(0.10746268656716418, 0.7285714285714285, 'X[4] <= 4.5\nentropy = 0.886\nsamples = 8\nvalue = [3.155, 7.226]'),
#  Text(0.10626865671641791, 0.7, 'X[0] <= 704.0\nentropy = 0.606\nsamples = 5\nvalue = [1.262, 7.226]'),
#  Text(0.10507462686567164, 0.6714285714285714, 'entropy = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.10746268656716418, 0.6714285714285714, 'entropy = -0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.10865671641791044, 0.7, 'entropy = -0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.12470149253731343, 0.7285714285714285, 'X[0] <= 747.0\nentropy = 0.805\nsamples = 203\nvalue = [117.992, 38.541]'),
#  Text(0.11492537313432835, 0.7, 'X[9] <= 168130.734\nentropy = 0.667\nsamples = 153\nvalue = [91.491, 19.27]'),
#  Text(0.10985074626865672, 0.6714285714285714, 'X[2] <= 0.5\nentropy = 0.325\nsamples = 123\nvalue = [76.348, 4.818]'),
#  Text(0.10865671641791044, 0.6428571428571429, 'entropy = 0.0\nsamples = 76\nvalue = [47.954, 0.0]'),
#  Text(0.11104477611940299, 0.6428571428571429, 'X[3] <= 37.5\nentropy = 0.597\nsamples = 47\nvalue = [28.394, 4.818]'),
#  Text(0.10985074626865672, 0.6142857142857143, 'X[8] <= 0.5\nentropy = 0.893\nsamples = 19\nvalue = [10.727, 4.818]'),
#  Text(0.10865671641791044, 0.5857142857142857, 'X[9] <= 81439.828\nentropy = 0.999\nsamples = 9\nvalue = [4.417, 4.818]'),
#  Text(0.10746268656716418, 0.5571428571428572, 'entropy = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.10985074626865672, 0.5571428571428572, 'X[9] <= 109998.758\nentropy = 0.858\nsamples = 5\nvalue = [1.893, 4.818]'),
#  Text(0.10865671641791044, 0.5285714285714286, 'X[0] <= 599.5\nentropy = 0.517\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.10746268656716418, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.10985074626865672, 0.5, 'X[4] <= 7.5\nentropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.10865671641791044, 0.4714285714285714, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.11104477611940299, 0.4714285714285714, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.11104477611940299, 0.5285714285714286, 'entropy = -0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.11104477611940299, 0.5857142857142857, 'entropy = -0.0\nsamples = 10\nvalue = [6.31, 0.0]'),
#  Text(0.11223880597014925, 0.6142857142857143, 'entropy = 0.0\nsamples = 28\nvalue = [17.667, 0.0]'),
#  Text(0.12, 0.6714285714285714, 'X[3] <= 38.5\nentropy = 1.0\nsamples = 30\nvalue = [15.143, 14.453]'),
#  Text(0.11701492537313433, 0.6428571428571429, 'X[0] <= 677.5\nentropy = 0.968\nsamples = 21\nvalue = [9.465, 14.453]'),
#  Text(0.11462686567164179, 0.6142857142857143, 'X[5] <= 95197.621\nentropy = 0.858\nsamples = 15\nvalue = [5.679, 14.453]'),
#  Text(0.11343283582089553, 0.5857142857142857, 'entropy = 0.0\nsamples = 4\nvalue = [0.0, 9.635]'),
#  Text(0.11582089552238806, 0.5857142857142857, 'X[5] <= 117014.215\nentropy = 0.995\nsamples = 11\nvalue = [5.679, 4.818]'),
#  Text(0.11462686567164179, 0.5571428571428572, 'entropy = 0.0\nsamples = 6\nvalue = [3.786, 0.0]'),
#  Text(0.11701492537313433, 0.5571428571428572, 'X[2] <= 0.5\nentropy = 0.858\nsamples = 5\nvalue = [1.893, 4.818]'),
#  Text(0.11582089552238806, 0.5285714285714286, 'entropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.1182089552238806, 0.5285714285714286, 'entropy = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.11940298507462686, 0.6142857142857143, 'X[3] <= 36.5\nentropy = 0.0\nsamples = 6\nvalue = [3.786, 0.0]'),
#  Text(0.1182089552238806, 0.5857142857142857, 'entropy = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.12059701492537313, 0.5857142857142857, 'entropy = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.12298507462686567, 0.6428571428571429, 'X[9] <= 173619.898\nentropy = 0.0\nsamples = 9\nvalue = [5.679, 0.0]'),
#  Text(0.1217910447761194, 0.6142857142857143, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.12417910447761193, 0.6142857142857143, 'entropy = 0.0\nsamples = 8\nvalue = [5.048, 0.0]'),
#  Text(0.1344776119402985, 0.7, 'X[9] <= 91330.332\nentropy = 0.982\nsamples = 50\nvalue = [26.501, 19.27]'),
#  Text(0.12925373134328358, 0.6714285714285714, 'X[5] <= 99791.629\nentropy = 0.912\nsamples = 20\nvalue = [8.203, 16.862]'),
#  Text(0.12805970149253731, 0.6428571428571429, 'entropy = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.13044776119402984, 0.6428571428571429, 'X[9] <= 86990.406\nentropy = 0.845\nsamples = 17\nvalue = [6.31, 16.862]'),
#  Text(0.1271641791044776, 0.6142857142857143, 'X[5] <= 135460.219\nentropy = 0.928\nsamples = 15\nvalue = [6.31, 12.044]'),
#  Text(0.12417910447761193, 0.5857142857142857, 'X[3] <= 37.5\nentropy = 0.794\nsamples = 11\nvalue = [3.786, 12.044]'),
#  Text(0.1217910447761194, 0.5571428571428572, 'X[0] <= 754.5\nentropy = 0.987\nsamples = 6\nvalue = [3.155, 2.409]'),
#  Text(0.12059701492537313, 0.5285714285714286, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.12298507462686567, 0.5285714285714286, 'entropy = -0.0\nsamples = 5\nvalue = [3.155, 0.0]'),
#  Text(0.1265671641791045, 0.5571428571428572, 'X[7] <= 0.5\nentropy = 0.333\nsamples = 5\nvalue = [0.631, 9.635]'),
#  Text(0.1253731343283582, 0.5285714285714286, 'X[4] <= 4.0\nentropy = 0.737\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.12417910447761193, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.1265671641791045, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.12776119402985076, 0.5285714285714286, 'entropy = -0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.13014925373134328, 0.5857142857142857, 'X[2] <= 0.5\nentropy = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.12895522388059702, 0.5571428571428572, 'entropy = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.13134328358208955, 0.5571428571428572, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.13373134328358208, 0.6142857142857143, 'X[3] <= 37.0\nentropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.1325373134328358, 0.5857142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.13492537313432837, 0.5857142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.13970149253731343, 0.6714285714285714, 'X[3] <= 38.5\nentropy = 0.519\nsamples = 30\nvalue = [18.298, 2.409]'),
#  Text(0.1373134328358209, 0.6428571428571429, 'X[0] <= 754.5\nentropy = 0.0\nsamples = 24\nvalue = [15.143, 0.0]'),
#  Text(0.13611940298507463, 0.6142857142857143, 'entropy = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.13850746268656716, 0.6142857142857143, 'entropy = 0.0\nsamples = 22\nvalue = [13.881, 0.0]'),
#  Text(0.14208955223880598, 0.6428571428571429, 'X[4] <= 1.5\nentropy = 0.987\nsamples = 6\nvalue = [3.155, 2.409]'),
#  Text(0.1408955223880597, 0.6142857142857143, 'X[0] <= 817.5\nentropy = 0.737\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.13970149253731343, 0.5857142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.14208955223880598, 0.5857142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.14328358208955225, 0.6142857142857143, 'entropy = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.14388059701492537, 0.8142857142857143, 'X[5] <= 181616.141\nentropy = 0.891\nsamples = 27\nvalue = [10.727, 24.088]'),
#  Text(0.1426865671641791, 0.7857142857142857, 'entropy = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.14507462686567163, 0.7857142857142857, 'X[3] <= 36.5\nentropy = 0.964\nsamples = 24\nvalue = [10.727, 16.862]'),
#  Text(0.14208955223880598, 0.7571428571428571, 'X[2] <= 0.5\nentropy = 0.871\nsamples = 18\nvalue = [6.941, 16.862]'),
#  Text(0.13970149253731343, 0.7285714285714285, 'X[3] <= 35.5\nentropy = 0.908\nsamples = 9\nvalue = [5.048, 2.409]'),
#  Text(0.13850746268656716, 0.7, 'entropy = -0.0\nsamples = 8\nvalue = [5.048, 0.0]'),
#  Text(0.1408955223880597, 0.7, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.1444776119402985, 0.7285714285714285, 'X[4] <= 7.5\nentropy = 0.517\nsamples = 9\nvalue = [1.893, 14.453]'),
#  Text(0.14328358208955225, 0.7, 'X[0] <= 467.5\nentropy = 0.251\nsamples = 7\nvalue = [0.631, 14.453]'),
#  Text(0.14208955223880598, 0.6714285714285714, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.1444776119402985, 0.6714285714285714, 'entropy = 0.0\nsamples = 6\nvalue = [0.0, 14.453]'),
#  Text(0.14567164179104478, 0.7, 'entropy = -0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.1480597014925373, 0.7571428571428571, 'X[3] <= 37.5\nentropy = 0.0\nsamples = 6\nvalue = [3.786, 0.0]'),
#  Text(0.14686567164179104, 0.7285714285714285, 'entropy = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.14925373134328357, 0.7285714285714285, 'entropy = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.23361940298507464, 0.8714285714285714, 'X[8] <= 0.5\nentropy = 0.998\nsamples = 966\nvalue = [493.42, 443.221]'),
#  Text(0.17694029850746268, 0.8428571428571429, 'X[0] <= 509.5\nentropy = 0.989\nsamples = 474\nvalue = [223.995, 286.648]'),
#  Text(0.15402985074626865, 0.8142857142857143, 'X[0] <= 390.5\nentropy = 0.707\nsamples = 34\nvalue = [20.191, 4.818]'),
#  Text(0.1528358208955224, 0.7857142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.15522388059701492, 0.7857142857142857, 'X[4] <= 8.5\nentropy = 0.49\nsamples = 33\nvalue = [20.191, 2.409]'),
#  Text(0.1528358208955224, 0.7571428571428571, 'X[2] <= 0.5\nentropy = 0.0\nsamples = 30\nvalue = [18.929, 0.0]'),
#  Text(0.15164179104477613, 0.7285714285714285, 'entropy = 0.0\nsamples = 19\nvalue = [11.988, 0.0]'),
#  Text(0.15402985074626865, 0.7285714285714285, 'entropy = 0.0\nsamples = 11\nvalue = [6.941, 0.0]'),
#  Text(0.15761194029850747, 0.7571428571428571, 'X[1] <= 1.5\nentropy = 0.928\nsamples = 3\nvalue = [1.262, 2.409]'),
#  Text(0.15641791044776118, 0.7285714285714285, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.15880597014925374, 0.7285714285714285, 'entropy = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.1998507462686567, 0.8142857142857143, 'X[2] <= 0.5\nentropy = 0.981\nsamples = 440\nvalue = [203.804, 281.831]'),
#  Text(0.1741044776119403, 0.7857142857142857, 'X[0] <= 632.5\nentropy = 1.0\nsamples = 240\nvalue = [120.516, 118.032]'),
#  Text(0.16417910447761194, 0.7571428571428571, 'X[9] <= 113453.156\nentropy = 0.951\nsamples = 94\nvalue = [41.013, 69.855]'),
#  Text(0.16119402985074627, 0.7285714285714285, 'X[5] <= 160560.727\nentropy = 0.851\nsamples = 59\nvalue = [22.084, 57.811]'),
#  Text(0.16, 0.7, 'X[9] <= 105707.953\nentropy = 0.785\nsamples = 52\nvalue = [17.667, 57.811]'),
#  Text(0.15880597014925374, 0.6714285714285714, 'X[7] <= 0.5\nentropy = 0.839\nsamples = 48\nvalue = [17.667, 48.176]'),
#  Text(0.15402985074626865, 0.6428571428571429, 'X[3] <= 35.5\nentropy = 1.0\nsamples = 15\nvalue = [7.572, 7.226]'),
#  Text(0.15164179104477613, 0.6142857142857143, 'X[5] <= 50676.391\nentropy = 0.0\nsamples = 9\nvalue = [5.679, 0.0]'),
#  Text(0.15044776119402986, 0.5857142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.1528358208955224, 0.5857142857142857, 'entropy = 0.0\nsamples = 8\nvalue = [5.048, 0.0]'),
#  Text(0.15641791044776118, 0.6142857142857143, 'X[4] <= 4.5\nentropy = 0.737\nsamples = 6\nvalue = [1.893, 7.226]'),
#  Text(0.15522388059701492, 0.5857142857142857, 'entropy = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.15761194029850747, 0.5857142857142857, 'entropy = -0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.1635820895522388, 0.6428571428571429, 'X[4] <= 8.5\nentropy = 0.717\nsamples = 33\nvalue = [10.096, 40.95]'),
#  Text(0.16238805970149253, 0.6142857142857143, 'X[4] <= 6.5\nentropy = 0.801\nsamples = 29\nvalue = [10.096, 31.315]'),
#  Text(0.16, 0.5857142857142857, 'X[5] <= 132136.402\nentropy = 0.644\nsamples = 21\nvalue = [5.679, 28.906]'),
#  Text(0.15880597014925374, 0.5571428571428572, 'X[0] <= 571.5\nentropy = 0.905\nsamples = 14\nvalue = [5.679, 12.044]'),
#  Text(0.15761194029850747, 0.5285714285714286, 'entropy = 0.0\nsamples = 6\nvalue = [3.786, 0.0]'),
#  Text(0.16, 0.5285714285714286, 'X[5] <= 119382.105\nentropy = 0.573\nsamples = 8\nvalue = [1.893, 12.044]'),
#  Text(0.15880597014925374, 0.5, 'X[1] <= 1.5\nentropy = 0.285\nsamples = 6\nvalue = [0.631, 12.044]'),
#  Text(0.15761194029850747, 0.4714285714285714, 'X[9] <= 71936.395\nentropy = 0.737\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.15641791044776118, 0.44285714285714284, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.15880597014925374, 0.44285714285714284, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.16, 0.4714285714285714, 'entropy = -0.0\nsamples = 4\nvalue = [0.0, 9.635]'),
#  Text(0.16119402985074627, 0.5, 'entropy = -0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.16119402985074627, 0.5571428571428572, 'entropy = 0.0\nsamples = 7\nvalue = [0.0, 16.862]'),
#  Text(0.1647761194029851, 0.5857142857142857, 'X[5] <= 46109.605\nentropy = 0.937\nsamples = 8\nvalue = [4.417, 2.409]'),
#  Text(0.1635820895522388, 0.5571428571428572, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.16597014925373135, 0.5571428571428572, 'entropy = -0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  Text(0.1647761194029851, 0.6142857142857143, 'entropy = -0.0\nsamples = 4\nvalue = [0.0, 9.635]'),
#  Text(0.16119402985074627, 0.6714285714285714, 'entropy = 0.0\nsamples = 4\nvalue = [0.0, 9.635]'),
#  Text(0.16238805970149253, 0.7, 'entropy = -0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  Text(0.16716417910447762, 0.7285714285714285, 'X[5] <= 121337.277\nentropy = 0.964\nsamples = 35\nvalue = [18.929, 12.044]'),
#  Text(0.1647761194029851, 0.7, 'X[4] <= 0.5\nentropy = 0.0\nsamples = 20\nvalue = [12.619, 0.0]'),
#  Text(0.1635820895522388, 0.6714285714285714, 'entropy = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.16597014925373135, 0.6714285714285714, 'entropy = 0.0\nsamples = 18\nvalue = [11.357, 0.0]'),
#  Text(0.16955223880597015, 0.7, 'X[5] <= 128842.766\nentropy = 0.928\nsamples = 15\nvalue = [6.31, 12.044]'),
#  Text(0.16835820895522388, 0.6714285714285714, 'entropy = 0.0\nsamples = 5\nvalue = [0.0, 12.044]'),
#  Text(0.1707462686567164, 0.6714285714285714, 'entropy = -0.0\nsamples = 10\nvalue = [6.31, 0.0]'),
#  Text(0.18402985074626865, 0.7571428571428571, 'X[9] <= 164340.555\nentropy = 0.956\nsamples = 146\nvalue = [79.502, 48.176]'),
#  Text(0.1782089552238806, 0.7285714285714285, 'X[5] <= 101965.473\nentropy = 0.874\nsamples = 122\nvalue = [69.407, 28.906]'),
#  Text(0.17701492537313432, 0.7, 'entropy = 0.0\nsamples = 37\nvalue = [23.346, 0.0]'),
#  Text(0.17940298507462688, 0.7, 'X[9] <= 131228.816\nentropy = 0.962\nsamples = 85\nvalue = [46.061, 28.906]'),
#  Text(0.1782089552238806, 0.6714285714285714, 'X[5] <= 121989.367\nentropy = 0.996\nsamples = 65\nvalue = [33.441, 28.906]'),
#  Text(0.17492537313432835, 0.6428571428571429, 'X[5] <= 121604.609\nentropy = 0.928\nsamples = 24\nvalue = [10.096, 19.27]'),
#  Text(0.17194029850746267, 0.6142857142857143, 'X[9] <= 97871.348\nentropy = 0.977\nsamples = 22\nvalue = [10.096, 14.453]'),
#  Text(0.16955223880597015, 0.5857142857142857, 'X[3] <= 29.5\nentropy = 0.928\nsamples = 18\nvalue = [7.572, 14.453]'),
#  Text(0.16835820895522388, 0.5571428571428572, 'entropy = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.1707462686567164, 0.5571428571428572, 'X[4] <= 2.5\nentropy = 0.886\nsamples = 16\nvalue = [6.31, 14.453]'),
#  Text(0.16835820895522388, 0.5285714285714286, 'X[9] <= 16135.545\nentropy = 0.987\nsamples = 6\nvalue = [3.155, 2.409]'),
#  Text(0.16716417910447762, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.16955223880597015, 0.5, 'entropy = -0.0\nsamples = 5\nvalue = [3.155, 0.0]'),
#  Text(0.17313432835820897, 0.5285714285714286, 'X[3] <= 31.0\nentropy = 0.737\nsamples = 10\nvalue = [3.155, 12.044]'),
#  Text(0.17194029850746267, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.17432835820895523, 0.5, 'X[9] <= 12929.06\nentropy = 0.573\nsamples = 8\nvalue = [1.893, 12.044]'),
#  Text(0.17313432835820897, 0.4714285714285714, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.1755223880597015, 0.4714285714285714, 'X[5] <= 111741.504\nentropy = 0.452\nsamples = 7\nvalue = [1.262, 12.044]'),
#  Text(0.17432835820895523, 0.44285714285714284, 'entropy = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.17671641791044776, 0.44285714285714284, 'X[5] <= 113467.844\nentropy = 0.737\nsamples = 4\nvalue = [1.262, 4.818]'),
#  Text(0.1755223880597015, 0.4142857142857143, 'entropy = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.17791044776119402, 0.4142857142857143, 'X[9] <= 73419.031\nentropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.17671641791044776, 0.38571428571428573, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.1791044776119403, 0.38571428571428573, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.17432835820895523, 0.5857142857142857, 'X[5] <= 105691.035\nentropy = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.17313432835820897, 0.5571428571428572, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.1755223880597015, 0.5571428571428572, 'entropy = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.17791044776119402, 0.6142857142857143, 'X[1] <= 1.5\nentropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.17671641791044776, 0.5857142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.1791044776119403, 0.5857142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.18149253731343284, 0.6428571428571429, 'X[9] <= 60318.354\nentropy = 0.871\nsamples = 41\nvalue = [23.346, 9.635]'),
#  Text(0.18029850746268658, 0.6142857142857143, 'entropy = 0.0\nsamples = 17\nvalue = [10.727, 0.0]'),
#  Text(0.1826865671641791, 0.6142857142857143, 'X[9] <= 64530.199\nentropy = 0.987\nsamples = 24\nvalue = [12.619, 9.635]'),
#  Text(0.18149253731343284, 0.5857142857142857, 'entropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.18388059701492537, 0.5857142857142857, 'X[4] <= 6.5\nentropy = 0.85\nsamples = 22\nvalue = [12.619, 4.818]'),
#  Text(0.18149253731343284, 0.5571428571428572, 'X[0] <= 644.0\nentropy = 0.0\nsamples = 15\nvalue = [9.465, 0.0]'),
#  Text(0.18029850746268658, 0.5285714285714286, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.1826865671641791, 0.5285714285714286, 'entropy = 0.0\nsamples = 14\nvalue = [8.834, 0.0]'),
#  Text(0.1862686567164179, 0.5571428571428572, 'X[5] <= 132350.742\nentropy = 0.968\nsamples = 7\nvalue = [3.155, 4.818]'),
#  Text(0.18507462686567164, 0.5285714285714286, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.18746268656716417, 0.5285714285714286, 'X[9] <= 84353.91\nentropy = 0.987\nsamples = 6\nvalue = [3.155, 2.409]'),
#  Text(0.1862686567164179, 0.5, 'entropy = 0.0\nsamples = 5\nvalue = [3.155, 0.0]'),
#  Text(0.18865671641791046, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.18059701492537314, 0.6714285714285714, 'entropy = 0.0\nsamples = 20\nvalue = [12.619, 0.0]'),
#  Text(0.18985074626865672, 0.7285714285714285, 'X[9] <= 189847.664\nentropy = 0.928\nsamples = 24\nvalue = [10.096, 19.27]'),
#  Text(0.18746268656716417, 0.7, 'X[0] <= 653.0\nentropy = 0.834\nsamples = 19\nvalue = [6.941, 19.27]'),
#  Text(0.1862686567164179, 0.6714285714285714, 'entropy = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.18865671641791046, 0.6714285714285714, 'X[4] <= 5.5\nentropy = 0.694\nsamples = 15\nvalue = [4.417, 19.27]'),
#  Text(0.1862686567164179, 0.6428571428571429, 'X[0] <= 670.0\nentropy = 0.251\nsamples = 7\nvalue = [0.631, 14.453]'),
#  Text(0.18507462686567164, 0.6142857142857143, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.18746268656716417, 0.6142857142857143, 'entropy = 0.0\nsamples = 6\nvalue = [0.0, 14.453]'),
#  Text(0.191044776119403, 0.6428571428571429, 'X[5] <= 110318.168\nentropy = 0.99\nsamples = 8\nvalue = [3.786, 4.818]'),
#  Text(0.18985074626865672, 0.6142857142857143, 'entropy = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.19223880597014925, 0.6142857142857143, 'X[5] <= 121616.016\nentropy = 0.858\nsamples = 5\nvalue = [1.893, 4.818]'),
#  Text(0.191044776119403, 0.5857142857142857, 'entropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.19343283582089552, 0.5857142857142857, 'entropy = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.19223880597014925, 0.7, 'X[9] <= 191905.945\nentropy = 0.0\nsamples = 5\nvalue = [3.155, 0.0]'),
#  Text(0.191044776119403, 0.6714285714285714, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.19343283582089552, 0.6714285714285714, 'entropy = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.22559701492537312, 0.7857142857142857, 'X[9] <= 73458.91\nentropy = 0.922\nsamples = 200\nvalue = [83.288, 163.799]'),
#  Text(0.21522388059701492, 0.7571428571428571, 'X[4] <= 9.5\nentropy = 0.772\nsamples = 72\nvalue = [23.977, 81.9]'),
#  Text(0.2128358208955224, 0.7285714285714285, 'X[5] <= 167335.859\nentropy = 0.717\nsamples = 64\nvalue = [19.56, 79.491]'),
#  Text(0.21164179104477612, 0.7, 'X[9] <= 65983.18\nentropy = 0.684\nsamples = 61\nvalue = [17.667, 79.491]'),
#  Text(0.21044776119402986, 0.6714285714285714, 'X[3] <= 38.5\nentropy = 0.737\nsamples = 56\nvalue = [17.667, 67.447]'),
#  Text(0.20597014925373133, 0.6428571428571429, 'X[3] <= 36.5\nentropy = 0.8\nsamples = 49\nvalue = [17.036, 52.994]'),
#  Text(0.20059701492537313, 0.6142857142857143, 'X[3] <= 32.5\nentropy = 0.721\nsamples = 41\nvalue = [12.619, 50.585]'),
#  Text(0.19582089552238807, 0.5857142857142857, 'X[9] <= 4940.255\nentropy = 0.914\nsamples = 23\nvalue = [9.465, 19.27]'),
#  Text(0.19462686567164178, 0.5571428571428572, 'entropy = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.19701492537313434, 0.5571428571428572, 'X[9] <= 6805.84\nentropy = 0.858\nsamples = 20\nvalue = [7.572, 19.27]'),
#  Text(0.19582089552238807, 0.5285714285714286, 'entropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.1982089552238806, 0.5285714285714286, 'X[0] <= 650.5\nentropy = 0.928\nsamples = 18\nvalue = [7.572, 14.453]'),
#  Text(0.19701492537313434, 0.5, 'entropy = 0.0\nsamples = 5\nvalue = [3.155, 0.0]'),
#  Text(0.19940298507462687, 0.5, 'X[9] <= 20239.564\nentropy = 0.785\nsamples = 13\nvalue = [4.417, 14.453]'),
#  Text(0.1982089552238806, 0.4714285714285714, 'entropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.20059701492537313, 0.4714285714285714, 'X[9] <= 28962.915\nentropy = 0.898\nsamples = 11\nvalue = [4.417, 9.635]'),
#  Text(0.19940298507462687, 0.44285714285714284, 'entropy = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.2017910447761194, 0.44285714285714284, 'X[0] <= 784.0\nentropy = 0.806\nsamples = 9\nvalue = [3.155, 9.635]'),
#  Text(0.20059701492537313, 0.4142857142857143, 'X[4] <= 0.5\nentropy = 0.644\nsamples = 7\nvalue = [1.893, 9.635]'),
#  Text(0.19940298507462687, 0.38571428571428573, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
# ...
#  Text(0.40044776119402986, 0.7857142857142857, 'X[3] <= 33.5\nentropy = 0.403\nsamples = 4\nvalue = [0.631, 7.226]'),
#  Text(0.39925373134328357, 0.7571428571428571, 'entropy = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.4016417910447761, 0.7571428571428571, 'entropy = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.4064179104477612, 0.7857142857142857, 'X[9] <= 106923.109\nentropy = 0.997\nsamples = 26\nvalue = [12.619, 14.453]'),
#  Text(0.4040298507462687, 0.7571428571428571, 'X[9] <= 20344.84\nentropy = 0.823\nsamples = 12\nvalue = [6.941, 2.409]'),
#  Text(0.4028358208955224, 0.7285714285714285, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.4052238805970149, 0.7285714285714285, 'entropy = 0.0\nsamples = 11\nvalue = [6.941, 0.0]'),
#  Text(0.40880597014925374, 0.7571428571428571, 'X[3] <= 31.5\nentropy = 0.905\nsamples = 14\nvalue = [5.679, 12.044]'),
#  Text(0.40761194029850745, 0.7285714285714285, 'entropy = 0.0\nsamples = 5\nvalue = [3.155, 0.0]'),
#  Text(0.41, 0.7285714285714285, 'X[9] <= 169187.32\nentropy = 0.665\nsamples = 9\nvalue = [2.524, 12.044]'),
#  Text(0.40880597014925374, 0.7, 'X[0] <= 658.0\nentropy = 0.452\nsamples = 7\nvalue = [1.262, 12.044]'),
#  Text(0.40761194029850745, 0.6714285714285714, 'X[4] <= 1.0\nentropy = 0.737\nsamples = 4\nvalue = [1.262, 4.818]'),
#  Text(0.4064179104477612, 0.6428571428571429, 'entropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.40880597014925374, 0.6428571428571429, 'X[0] <= 601.5\nentropy = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.40761194029850745, 0.6142857142857143, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.41, 0.6142857142857143, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.41, 0.6714285714285714, 'entropy = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.41119402985074627, 0.7, 'entropy = -0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.44904850746268654, 0.8428571428571429, 'X[5] <= 205016.172\nentropy = 0.794\nsamples = 526\nvalue = [306.652, 96.352]'),
#  Text(0.43906716417910446, 0.8142857142857143, 'X[9] <= 176848.469\nentropy = 0.771\nsamples = 521\nvalue = [305.39, 89.126]'),
#  Text(0.4378731343283582, 0.7857142857142857, 'X[2] <= 0.5\nentropy = 0.811\nsamples = 461\nvalue = [267.532, 89.126]'),
#  Text(0.42149253731343284, 0.7571428571428571, 'X[5] <= 122665.535\nentropy = 0.643\nsamples = 267\nvalue = [160.267, 31.315]'),
#  Text(0.42029850746268654, 0.7285714285714285, 'entropy = 0.0\nsamples = 59\nvalue = [37.227, 0.0]'),
#  Text(0.42268656716417913, 0.7285714285714285, 'X[1] <= 1.5\nentropy = 0.728\nsamples = 208\nvalue = [123.039, 31.315]'),
#  Text(0.42149253731343284, 0.7, 'X[5] <= 165449.797\nentropy = 0.799\nsamples = 168\nvalue = [97.801, 31.315]'),
#  Text(0.42029850746268654, 0.6714285714285714, 'X[5] <= 143855.531\nentropy = 0.863\nsamples = 137\nvalue = [78.24, 31.315]'),
#  Text(0.4135820895522388, 0.6428571428571429, 'X[5] <= 122950.035\nentropy = 0.627\nsamples = 86\nvalue = [51.74, 9.635]'),
#  Text(0.41238805970149256, 0.6142857142857143, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.4147761194029851, 0.6142857142857143, 'X[9] <= 152080.727\nentropy = 0.537\nsamples = 85\nvalue = [51.74, 7.226]'),
#  Text(0.41238805970149256, 0.5857142857142857, 'X[4] <= 1.5\nentropy = 0.291\nsamples = 72\nvalue = [44.799, 2.409]'),
#  Text(0.41119402985074627, 0.5571428571428572, 'X[3] <= 36.0\nentropy = 0.937\nsamples = 8\nvalue = [4.417, 2.409]'),
#  Text(0.41, 0.5285714285714286, 'X[4] <= 0.5\nentropy = 0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  Text(0.40880597014925374, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.41119402985074627, 0.5, 'entropy = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.41238805970149256, 0.5285714285714286, 'entropy = -0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.4135820895522388, 0.5571428571428572, 'entropy = 0.0\nsamples = 64\nvalue = [40.382, 0.0]'),
#  Text(0.4171641791044776, 0.5857142857142857, 'X[9] <= 160718.242\nentropy = 0.976\nsamples = 13\nvalue = [6.941, 4.818]'),
#  Text(0.4159701492537313, 0.5571428571428572, 'X[3] <= 38.0\nentropy = 0.517\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.4147761194029851, 0.5285714285714286, 'X[9] <= 156362.992\nentropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.4135820895522388, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.4159701492537313, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.4171641791044776, 0.5285714285714286, 'entropy = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.41835820895522385, 0.5571428571428572, 'entropy = -0.0\nsamples = 10\nvalue = [6.31, 0.0]'),
#  Text(0.42701492537313435, 0.6428571428571429, 'X[5] <= 144394.617\nentropy = 0.993\nsamples = 51\nvalue = [26.501, 21.679]'),
#  Text(0.42582089552238805, 0.6142857142857143, 'entropy = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.4282089552238806, 0.6142857142857143, 'X[9] <= 101773.469\nentropy = 0.937\nsamples = 48\nvalue = [26.501, 14.453]'),
#  Text(0.42701492537313435, 0.5857142857142857, 'X[0] <= 722.5\nentropy = 1.0\nsamples = 28\nvalue = [13.881, 14.453]'),
#  Text(0.4237313432835821, 0.5571428571428572, 'X[5] <= 161118.172\nentropy = 0.984\nsamples = 23\nvalue = [10.727, 14.453]'),
#  Text(0.42074626865671644, 0.5285714285714286, 'X[5] <= 154608.5\nentropy = 1.0\nsamples = 20\nvalue = [10.096, 9.635]'),
#  Text(0.41835820895522385, 0.5, 'X[9] <= 36975.475\nentropy = 0.951\nsamples = 13\nvalue = [5.679, 9.635]'),
#  Text(0.4171641791044776, 0.4714285714285714, 'entropy = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.41955223880597015, 0.4714285714285714, 'X[0] <= 569.5\nentropy = 0.858\nsamples = 10\nvalue = [3.786, 9.635]'),
#  Text(0.41835820895522385, 0.44285714285714284, 'entropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.42074626865671644, 0.44285714285714284, 'X[3] <= 34.0\nentropy = 0.99\nsamples = 8\nvalue = [3.786, 4.818]'),
#  Text(0.41955223880597015, 0.4142857142857143, 'X[0] <= 614.5\nentropy = 0.737\nsamples = 4\nvalue = [1.262, 4.818]'),
#  Text(0.41835820895522385, 0.38571428571428573, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.42074626865671644, 0.38571428571428573, 'X[9] <= 96134.152\nentropy = 0.517\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.41955223880597015, 0.35714285714285715, 'X[4] <= 2.5\nentropy = 0.737\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.41835820895522385, 0.32857142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.42074626865671644, 0.32857142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.4219402985074627, 0.35714285714285715, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.4219402985074627, 0.4142857142857143, 'entropy = -0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.42313432835820897, 0.5, 'X[5] <= 154806.766\nentropy = 0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  Text(0.4219402985074627, 0.4714285714285714, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.4243283582089552, 0.4714285714285714, 'entropy = 0.0\nsamples = 6\nvalue = [3.786, 0.0]'),
#  Text(0.4267164179104478, 0.5285714285714286, 'X[1] <= 0.5\nentropy = 0.517\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.4255223880597015, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.427910447761194, 0.5, 'entropy = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.43029850746268655, 0.5571428571428572, 'X[5] <= 153443.125\nentropy = 0.0\nsamples = 5\nvalue = [3.155, 0.0]'),
#  Text(0.4291044776119403, 0.5285714285714286, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.43149253731343284, 0.5285714285714286, 'entropy = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.4294029850746269, 0.5857142857142857, 'entropy = -0.0\nsamples = 20\nvalue = [12.619, 0.0]'),
#  Text(0.42268656716417913, 0.6714285714285714, 'entropy = 0.0\nsamples = 31\nvalue = [19.56, 0.0]'),
#  Text(0.42388059701492536, 0.7, 'entropy = 0.0\nsamples = 40\nvalue = [25.239, 0.0]'),
#  Text(0.45425373134328356, 0.7571428571428571, 'X[9] <= 172711.055\nentropy = 0.934\nsamples = 194\nvalue = [107.265, 57.811]'),
#  Text(0.4456716417910448, 0.7285714285714285, 'X[5] <= 134547.008\nentropy = 0.896\nsamples = 188\nvalue = [106.003, 48.176]'),
#  Text(0.4374626865671642, 0.7, 'X[5] <= 122679.371\nentropy = 0.985\nsamples = 98\nvalue = [51.74, 38.541]'),
#  Text(0.4329850746268657, 0.6714285714285714, 'X[0] <= 564.0\nentropy = 0.59\nsamples = 48\nvalue = [29.025, 4.818]'),
#  Text(0.4317910447761194, 0.6428571428571429, 'X[9] <= 89479.559\nentropy = 0.99\nsamples = 8\nvalue = [3.786, 4.818]'),
#  Text(0.4305970149253731, 0.6142857142857143, 'entropy = 0.0\nsamples = 6\nvalue = [3.786, 0.0]'),
#  Text(0.4329850746268657, 0.6142857142857143, 'entropy = -0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.43417910447761193, 0.6428571428571429, 'entropy = -0.0\nsamples = 40\nvalue = [25.239, 0.0]'),
#  Text(0.4419402985074627, 0.6714285714285714, 'X[9] <= 62030.971\nentropy = 0.972\nsamples = 50\nvalue = [22.715, 33.723]'),
#  Text(0.43776119402985075, 0.6428571428571429, 'X[3] <= 31.5\nentropy = 0.737\nsamples = 20\nvalue = [6.31, 24.088]'),
#  Text(0.4353731343283582, 0.6142857142857143, 'X[9] <= 57809.865\nentropy = 0.964\nsamples = 7\nvalue = [3.786, 2.409]'),
#  Text(0.43417910447761193, 0.5857142857142857, 'entropy = -0.0\nsamples = 6\nvalue = [3.786, 0.0]'),
#  Text(0.43656716417910446, 0.5857142857142857, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.4401492537313433, 0.6142857142857143, 'X[0] <= 534.0\nentropy = 0.482\nsamples = 13\nvalue = [2.524, 21.679]'),
#  Text(0.438955223880597, 0.5857142857142857, 'entropy = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.4413432835820896, 0.5857142857142857, 'X[8] <= 0.5\nentropy = 0.307\nsamples = 11\nvalue = [1.262, 21.679]'),
#  Text(0.4401492537313433, 0.5571428571428572, 'entropy = 0.0\nsamples = 5\nvalue = [0.0, 12.044]'),
#  Text(0.4425373134328358, 0.5571428571428572, 'X[9] <= 21581.325\nentropy = 0.517\nsamples = 6\nvalue = [1.262, 9.635]'),
#  Text(0.4413432835820896, 0.5285714285714286, 'entropy = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.4437313432835821, 0.5285714285714286, 'X[5] <= 125285.23\nentropy = 0.928\nsamples = 3\nvalue = [1.262, 2.409]'),
#  Text(0.4425373134328358, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.44492537313432834, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.44611940298507463, 0.6428571428571429, 'X[5] <= 123841.617\nentropy = 0.951\nsamples = 30\nvalue = [16.405, 9.635]'),
#  Text(0.44492537313432834, 0.6142857142857143, 'entropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.44731343283582087, 0.6142857142857143, 'X[3] <= 36.5\nentropy = 0.773\nsamples = 28\nvalue = [16.405, 4.818]'),
#  Text(0.44611940298507463, 0.5857142857142857, 'entropy = -0.0\nsamples = 21\nvalue = [13.25, 0.0]'),
#  Text(0.44850746268656716, 0.5857142857142857, 'X[0] <= 645.5\nentropy = 0.968\nsamples = 7\nvalue = [3.155, 4.818]'),
#  Text(0.44731343283582087, 0.5571428571428572, 'entropy = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.44970149253731345, 0.5571428571428572, 'X[3] <= 37.5\nentropy = 0.737\nsamples = 4\nvalue = [1.262, 4.818]'),
#  Text(0.44850746268656716, 0.5285714285714286, 'X[4] <= 5.0\nentropy = 0.517\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.44731343283582087, 0.5, 'X[9] <= 110848.137\nentropy = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.44611940298507463, 0.4714285714285714, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.44850746268656716, 0.4714285714285714, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.44970149253731345, 0.5, 'entropy = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.4508955223880597, 0.5285714285714286, 'entropy = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.4538805970149254, 0.7, 'X[5] <= 166705.188\nentropy = 0.612\nsamples = 90\nvalue = [54.264, 9.635]'),
#  Text(0.44970149253731345, 0.6714285714285714, 'X[0] <= 843.5\nentropy = 0.297\nsamples = 70\nvalue = [43.537, 2.409]'),
#  Text(0.44850746268656716, 0.6428571428571429, 'entropy = -0.0\nsamples = 68\nvalue = [42.906, 0.0]'),
#  Text(0.4508955223880597, 0.6428571428571429, 'X[1] <= 1.0\nentropy = 0.737\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.44970149253731345, 0.6142857142857143, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.452089552238806, 0.6142857142857143, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.45805970149253733, 0.6714285714285714, 'X[9] <= 125359.926\nentropy = 0.972\nsamples = 20\nvalue = [10.727, 7.226]'),
#  Text(0.4556716417910448, 0.6428571428571429, 'X[8] <= 0.5\nentropy = 0.0\nsamples = 14\nvalue = [8.834, 0.0]'),
#  Text(0.4544776119402985, 0.6142857142857143, 'entropy = 0.0\nsamples = 10\nvalue = [6.31, 0.0]'),
#  Text(0.45686567164179104, 0.6142857142857143, 'entropy = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.46044776119402986, 0.6428571428571429, 'X[9] <= 139176.328\nentropy = 0.737\nsamples = 6\nvalue = [1.893, 7.226]'),
#  Text(0.45925373134328357, 0.6142857142857143, 'entropy = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.4616417910447761, 0.6142857142857143, 'entropy = -0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.4628358208955224, 0.7285714285714285, 'X[0] <= 639.0\nentropy = 0.517\nsamples = 6\nvalue = [1.262, 9.635]'),
#  Text(0.4616417910447761, 0.7, 'X[0] <= 511.5\nentropy = 0.333\nsamples = 5\nvalue = [0.631, 9.635]'),
#  Text(0.46044776119402986, 0.6714285714285714, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.4628358208955224, 0.6714285714285714, 'entropy = 0.0\nsamples = 4\nvalue = [0.0, 9.635]'),
#  Text(0.4640298507462687, 0.7, 'entropy = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.44026119402985076, 0.7857142857142857, 'entropy = 0.0\nsamples = 60\nvalue = [37.858, 0.0]'),
#  Text(0.4590298507462687, 0.8142857142857143, 'X[2] <= 0.5\nentropy = 0.606\nsamples = 5\nvalue = [1.262, 7.226]'),
#  Text(0.4578358208955224, 0.7857142857142857, 'X[7] <= 0.5\nentropy = 0.403\nsamples = 4\nvalue = [0.631, 7.226]'),
#  Text(0.45664179104477615, 0.7571428571428571, 'entropy = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.4590298507462687, 0.7571428571428571, 'entropy = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.4602238805970149, 0.7857142857142857, 'entropy = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.4792537313432836, 0.9285714285714286, 'X[5] <= 23194.08\nentropy = 0.403\nsamples = 84\nvalue = [13.25, 151.755]'),
#  Text(0.47417910447761197, 0.9, 'X[9] <= 167555.125\nentropy = 0.776\nsamples = 32\nvalue = [10.727, 36.132]'),
#  Text(0.4729850746268657, 0.8714285714285714, 'X[3] <= 37.5\nentropy = 0.916\nsamples = 26\nvalue = [10.727, 21.679]'),
#  Text(0.47, 0.8428571428571429, 'X[4] <= 9.5\nentropy = 0.984\nsamples = 23\nvalue = [10.727, 14.453]'),
#  Text(0.46761194029850744, 0.8142857142857143, 'X[3] <= 29.5\nentropy = 0.998\nsamples = 21\nvalue = [10.727, 9.635]'),
#  Text(0.4664179104477612, 0.7857142857142857, 'entropy = 0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  Text(0.46880597014925374, 0.7857142857142857, 'X[9] <= 79541.242\nentropy = 0.968\nsamples = 14\nvalue = [6.31, 9.635]'),
#  Text(0.4664179104477612, 0.7571428571428571, 'X[0] <= 690.0\nentropy = 0.606\nsamples = 5\nvalue = [1.262, 7.226]'),
#  Text(0.4652238805970149, 0.7285714285714285, 'entropy = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.46761194029850744, 0.7285714285714285, 'entropy = -0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.47119402985074627, 0.7571428571428571, 'X[3] <= 30.5\nentropy = 0.908\nsamples = 9\nvalue = [5.048, 2.409]'),
#  Text(0.47, 0.7285714285714285, 'X[4] <= 2.5\nentropy = 0.737\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.46880597014925374, 0.7, 'entropy = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.47119402985074627, 0.7, 'entropy = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.47238805970149256, 0.7285714285714285, 'entropy = 0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  ...]

# %% [markdown]
# # 衡量模型

# %%
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
ori_predictions = ori_clf.predict(x_test) #用決策樹預測測試資料
ori_scores = cross_val_score(ori_clf,x_test,y_test, cv=10) #10-fold cross validation score
print("%0.3f accuracy with a standard deviation of %0.3f" % (ori_scores.mean(), ori_scores.std()))
# Out:
# 0.799 accuracy with a standard deviation of 0.016

# %%
ori_cm = confusion_matrix(y_test,ori_predictions, labels=ori_clf.classes_) #混淆矩陣
ori_disp = ConfusionMatrixDisplay(confusion_matrix=ori_cm, display_labels=ori_clf.classes_)
ori_disp.plot()

plt.show()

# %%
ori_accuracy = (ori_cm[0,0]+ori_cm[1,1])/3000
ori_recall = ori_cm[1,1]/(ori_cm[1,0]+ori_cm[1,1]) #計算recall
ori_precision = ori_cm[1,1]/(ori_cm[1,1]+ori_cm[0,1]) #計算precision
ori_F1 = 2 * (ori_precision * ori_recall) / (ori_precision + ori_recall) #計算F1
print("Accuracy: \t%0.3f" % (ori_accuracy))
print("Precision: \t%0.3f" % (ori_precision))
print("Recall: \t%0.3f" % (ori_recall))
print("F1 score: \t%0.3f" % (ori_F1))
# Out:
# Accuracy: 	0.794
# Precision: 	0.471
# Recall: 	0.486
# F1 score: 	0.479

# %%
import graphviz 
ori_dot_data2 = tree.export_graphviz(ori_clf, out_file=None, 
                     feature_names=feature_cols,  
                     class_names=['0','1'],  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(ori_dot_data2)  
graph.render("ori_tree_entropy")
# Out:
# 'ori_tree_entropy.pdf'

# %% [markdown]
# # 設置max_leaf_nodes

# %%
for i in range (2,20) :
    test_my_clf = tree.DecisionTreeClassifier(criterion = "entropy",splitter = "best",max_leaf_nodes= i)
    test_my_clf =  test_my_clf.fit(x_train,y_train)
    test_my_clf.score(x_test,y_test)
    scores = cross_val_score(test_my_clf,x_test,y_test, cv=10)
    predictions = test_my_clf.predict(x_test)
    cm = confusion_matrix(y_test, predictions, labels=test_my_clf.classes_)
    ori_accuracy = (ori_cm[0,0]+ori_cm[1,1])/3000
    ori_recall = ori_cm[1,1]/(ori_cm[1,0]+ori_cm[1,1]) #計算recall
    ori_precision = ori_cm[1,1]/(ori_cm[1,1]+ori_cm[0,1]) #計算precision
    ori_F1 = 2 * (ori_precision * ori_recall) / (ori_precision + ori_recall) #計算F1
    print("Accuracy: \t%0.3f" % (ori_accuracy))
    print("Precision: \t%0.3f" % (ori_precision))
    print("Recall: \t%0.3f" % (ori_recall))
    print("F1 score: \t%0.3f" % (ori_F1))
    print("%0.3f accuracy with a standard deviation of %0.3f, max_leaf_nodes = %i" % (scores.mean(), scores.std(),i))
    print("---------------------")
# Out:
# Accuracy: 	0.794
# Precision: 	0.471
# Recall: 	0.486
# F1 score: 	0.479
# 0.805 accuracy with a standard deviation of 0.002, max_leaf_nodes = 2
# ---------------------
# Accuracy: 	0.794
# Precision: 	0.471
# Recall: 	0.486
# F1 score: 	0.479
# 0.832 accuracy with a standard deviation of 0.013, max_leaf_nodes = 3
# ---------------------
# Accuracy: 	0.794
# Precision: 	0.471
# Recall: 	0.486
# F1 score: 	0.479
# 0.838 accuracy with a standard deviation of 0.010, max_leaf_nodes = 4
# ---------------------
# Accuracy: 	0.794
# Precision: 	0.471
# Recall: 	0.486
# F1 score: 	0.479
# 0.838 accuracy with a standard deviation of 0.010, max_leaf_nodes = 5
# ---------------------
# Accuracy: 	0.794
# Precision: 	0.471
# Recall: 	0.486
# F1 score: 	0.479
# 0.843 accuracy with a standard deviation of 0.011, max_leaf_nodes = 6
# ---------------------
# Accuracy: 	0.794
# Precision: 	0.471
# Recall: 	0.486
# F1 score: 	0.479
# 0.845 accuracy with a standard deviation of 0.009, max_leaf_nodes = 7
# ---------------------
# Accuracy: 	0.794
# Precision: 	0.471
# Recall: 	0.486
# F1 score: 	0.479
# 0.846 accuracy with a standard deviation of 0.009, max_leaf_nodes = 8
# ---------------------
# Accuracy: 	0.794
# Precision: 	0.471
# Recall: 	0.486
# F1 score: 	0.479
# 0.849 accuracy with a standard deviation of 0.007, max_leaf_nodes = 9
# ---------------------
# Accuracy: 	0.794
# Precision: 	0.471
# Recall: 	0.486
# F1 score: 	0.479
# 0.853 accuracy with a standard deviation of 0.006, max_leaf_nodes = 10
# ---------------------
# Accuracy: 	0.794
# Precision: 	0.471
# Recall: 	0.486
# F1 score: 	0.479
# 0.856 accuracy with a standard deviation of 0.007, max_leaf_nodes = 11
# ---------------------
# Accuracy: 	0.794
# Precision: 	0.471
# Recall: 	0.486
# F1 score: 	0.479
# 0.860 accuracy with a standard deviation of 0.010, max_leaf_nodes = 12
# ---------------------
# Accuracy: 	0.794
# Precision: 	0.471
# Recall: 	0.486
# F1 score: 	0.479
# 0.860 accuracy with a standard deviation of 0.010, max_leaf_nodes = 13
# ---------------------
# Accuracy: 	0.794
# Precision: 	0.471
# Recall: 	0.486
# F1 score: 	0.479
# 0.860 accuracy with a standard deviation of 0.011, max_leaf_nodes = 14
# ---------------------
# Accuracy: 	0.794
# Precision: 	0.471
# Recall: 	0.486
# F1 score: 	0.479
# 0.859 accuracy with a standard deviation of 0.010, max_leaf_nodes = 15
# ---------------------
# Accuracy: 	0.794
# Precision: 	0.471
# Recall: 	0.486
# F1 score: 	0.479
# 0.860 accuracy with a standard deviation of 0.009, max_leaf_nodes = 16
# ---------------------
# Accuracy: 	0.794
# Precision: 	0.471
# Recall: 	0.486
# F1 score: 	0.479
# 0.859 accuracy with a standard deviation of 0.011, max_leaf_nodes = 17
# ---------------------
# Accuracy: 	0.794
# Precision: 	0.471
# Recall: 	0.486
# F1 score: 	0.479
# 0.860 accuracy with a standard deviation of 0.008, max_leaf_nodes = 18
# ---------------------
# Accuracy: 	0.794
# Precision: 	0.471
# Recall: 	0.486
# F1 score: 	0.479
# 0.860 accuracy with a standard deviation of 0.008, max_leaf_nodes = 19
# ---------------------

# %%
my_clf = tree.DecisionTreeClassifier(criterion = "entropy",splitter = "best",max_leaf_nodes = 12)
my_clf = my_clf.fit(x_train,y_train)
scores = cross_val_score(my_clf,x_test,y_test, cv=10)

# %%
tree.plot_tree(my_clf)
# Out:
# [Text(0.5294117647058824, 0.9166666666666666, 'X[3] <= 41.5\nentropy = 0.737\nsamples = 7000\nvalue = [5547, 1453]'),
#  Text(0.29411764705882354, 0.75, 'X[6] <= 2.5\nentropy = 0.515\nsamples = 4748\nvalue = [4202, 546]'),
#  Text(0.23529411764705882, 0.5833333333333334, 'X[6] <= 1.5\nentropy = 0.471\nsamples = 4644\nvalue = [4177, 467]'),
#  Text(0.11764705882352941, 0.4166666666666667, 'X[3] <= 38.5\nentropy = 0.634\nsamples = 2302\nvalue = [1934, 368]'),
#  Text(0.058823529411764705, 0.25, 'entropy = 0.568\nsamples = 1869\nvalue = [1619, 250]'),
#  Text(0.17647058823529413, 0.25, 'entropy = 0.845\nsamples = 433\nvalue = [315, 118]'),
#  Text(0.35294117647058826, 0.4166666666666667, 'X[5] <= 108284.738\nentropy = 0.253\nsamples = 2342\nvalue = [2243, 99]'),
#  Text(0.29411764705882354, 0.25, 'entropy = 0.165\nsamples = 1726\nvalue = [1684, 42]'),
#  Text(0.4117647058823529, 0.25, 'entropy = 0.445\nsamples = 616\nvalue = [559, 57]'),
#  Text(0.35294117647058826, 0.5833333333333334, 'entropy = 0.796\nsamples = 104\nvalue = [25, 79]'),
#  Text(0.7647058823529411, 0.75, 'X[8] <= 0.5\nentropy = 0.973\nsamples = 2252\nvalue = [1345, 907]'),
#  Text(0.6470588235294118, 0.5833333333333334, 'X[3] <= 50.5\nentropy = 0.989\nsamples = 1035\nvalue = [453, 582]'),
#  Text(0.5882352941176471, 0.4166666666666667, 'X[6] <= 1.5\nentropy = 0.991\nsamples = 727\nvalue = [405, 322]'),
#  Text(0.5294117647058824, 0.25, 'entropy = 0.986\nsamples = 424\nvalue = [183, 241]'),
#  Text(0.6470588235294118, 0.25, 'X[6] <= 2.5\nentropy = 0.838\nsamples = 303\nvalue = [222, 81]'),
#  Text(0.5882352941176471, 0.08333333333333333, 'entropy = 0.626\nsamples = 262\nvalue = [221, 41]'),
#  Text(0.7058823529411765, 0.08333333333333333, 'entropy = 0.165\nsamples = 41\nvalue = [1, 40]'),
#  Text(0.7058823529411765, 0.4166666666666667, 'entropy = 0.624\nsamples = 308\nvalue = [48, 260]'),
#  Text(0.8823529411764706, 0.5833333333333334, 'X[6] <= 2.5\nentropy = 0.837\nsamples = 1217\nvalue = [892, 325]'),
#  Text(0.8235294117647058, 0.4166666666666667, 'X[6] <= 1.5\nentropy = 0.787\nsamples = 1162\nvalue = [889, 273]'),
#  Text(0.7647058823529411, 0.25, 'entropy = 0.913\nsamples = 649\nvalue = [436, 213]'),
#  Text(0.8823529411764706, 0.25, 'entropy = 0.521\nsamples = 513\nvalue = [453, 60]'),
#  Text(0.9411764705882353, 0.4166666666666667, 'entropy = 0.305\nsamples = 55\nvalue = [3, 52]')]

# %% [markdown]
# # 衡量新樹

# %%
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(my_clf,x_test,y_test, cv=10)
print("%0.3f accuracy with a standard deviation of %0.3f" % (scores.mean(), scores.std()))
# Out:
# 0.860 accuracy with a standard deviation of 0.010

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
predictions = my_clf.predict(x_test)
cm = confusion_matrix(y_test, predictions, labels=my_clf.classes_)
disp = ConfusionMatrixDisplay( confusion_matrix=cm , display_labels=my_clf.classes_)
disp.plot()

plt.show()

# %%
accuracy = (cm[0,0]+cm[1,1])/3000
recall = cm[1,1]/(cm[1,0]+cm[1,1]) #計算recall
precision = cm[1,1]/(cm[1,1]+cm[0,1]) #計算precision
F1 = 2 * (precision * recall) / (precision + recall) #計算F1
print("Accuracy: \t%0.3f" % (accuracy))
print("Precision: \t%0.3f" % (precision))
print("Recall: \t%0.3f" % (recall))
print("F1 score: \t%0.3f" % (F1))
# Out:
# Accuracy: 	0.859
# Precision: 	0.718
# Recall: 	0.457
# F1 score: 	0.559

# %%
import graphviz 
dot_data = tree.export_graphviz(my_clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("my_tree_entropy")
# Out:
# 'my_tree_entropy.pdf'

# %%
dot_data2 = tree.export_graphviz(my_clf, out_file=None, 
                     feature_names=feature_cols,  
                     class_names=['0','1'],  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data2)  
graph.render("my_tree_entropy2")
# Out:
# 'my_tree_entropy2.pdf'
