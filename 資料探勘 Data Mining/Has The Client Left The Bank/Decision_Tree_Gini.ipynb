# %%
import pandas as pd

# %%
data_base = pd.read_csv('Bank_Customer.csv') #讀入資料庫

# %%
data_base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
data_base.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %% [markdown]
# # 資料處理

# %%
import numpy as np

# %%
feature_cols = ['credit_score','country','gender','age','tenure','balance','products_number','credit_card','active_member','estimated_salary']

# %%
data = data_base.loc[:, feature_cols]

# %%
data.head()
# Out:
#    credit_score country  gender  age  tenure    balance  products_number  \
# 0           619  France  Female   42       2       0.00                1
# 1           608   Spain  Female   41       1   83807.86                1
# 2           502  France  Female   42       8  159660.80                3
# 3           699  France  Female   39       1       0.00                2
# 4           850   Spain  Female   43       2  125510.82                1
#
#    credit_card  active_member  estimated_salary
# 0            1              1         101348.88
# 1            0              1         112542.58
# 2            1              0         113931.57
# 3            0              0          93826.63
# 4            1              1          79084.10

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   credit_score      10000 non-null  int64
#  1   country           10000 non-null  object
#  2   gender            10000 non-null  object
#  3   age               10000 non-null  int64
#  4   tenure            10000 non-null  int64
#  5   balance           10000 non-null  float64
#  6   products_number   10000 non-null  int64
#  7   credit_card       10000 non-null  int64
#  8   active_member     10000 non-null  int64
#  9   estimated_salary  10000 non-null  float64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 781.4+ KB

# %%
target = data_base.churn.values

# %%
target
# Out:
# array([1, 0, 1, ..., 1, 1, 0], dtype=int64)

# %%
data_country = data['country']
data_gender = data['gender']
for i in range(0,10000):
    if(data_country[i] == 'France'):
        data_country[i] = 0
    elif(data_country[i] == 'Germany'):
        data_country[i] = 1
    elif(data_country[i] == 'Spain'):
        data_country[i] = 2
    if(data_gender[i] == 'Male'):
        data_gender[i] = 0
    elif(data_gender[i] == 'Female'):
        data_gender[i] = 1
# Out:
# C:\Users\annie\AppData\Local\Temp\ipykernel_25948\2712572799.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_country[i] = 0
# C:\Users\annie\AppData\Local\Temp\ipykernel_25948\2712572799.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_gender[i] = 1
# C:\Users\annie\AppData\Local\Temp\ipykernel_25948\2712572799.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_country[i] = 2
# C:\Users\annie\AppData\Local\Temp\ipykernel_25948\2712572799.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_gender[i] = 0
# C:\Users\annie\AppData\Local\Temp\ipykernel_25948\2712572799.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_country[i] = 1

# %%
data.head()
# Out:
#    credit_score country gender  age  tenure    balance  products_number  \
# 0           619       0      1   42       2       0.00                1
# 1           608       2      1   41       1   83807.86                1
# 2           502       0      1   42       8  159660.80                3
# 3           699       0      1   39       1       0.00                2
# 4           850       2      1   43       2  125510.82                1
#
#    credit_card  active_member  estimated_salary
# 0            1              1         101348.88
# 1            0              1         112542.58
# 2            1              0         113931.57
# 3            0              0          93826.63
# 4            1              1          79084.10

# %%
data['country'] = data['country'].astype(int)
data['gender'] = data['gender'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   credit_score      10000 non-null  int64
#  1   country           10000 non-null  int32
#  2   gender            10000 non-null  int32
#  3   age               10000 non-null  int64
#  4   tenure            10000 non-null  int64
#  5   balance           10000 non-null  float64
#  6   products_number   10000 non-null  int64
#  7   credit_card       10000 non-null  int64
#  8   active_member     10000 non-null  int64
#  9   estimated_salary  10000 non-null  float64
# dtypes: float64(2), int32(2), int64(6)
# memory usage: 703.2 KB

# %% [markdown]
# # 訓練資料與測試資料

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(data,target,test_size=0.3,random_state = 42)

# %%
x_train.shape
# Out:
# (7000, 10)

# %%
y_train.shape
# Out:
# (7000,)

# %%
x_test.shape
# Out:
# (3000, 10)

# %%
y_test.shape
# Out:
# (3000,)

# %% [markdown]
# # 建立決策樹

# %%
from sklearn import tree

# %%
ori_clf = tree.DecisionTreeClassifier(class_weight="balanced")
ori_clf = ori_clf.fit(x_train,y_train)

# %%
tree.plot_tree(ori_clf)
# Out:
# [Text(0.565663660112916, 0.9821428571428571, 'X[3] <= 39.5\ngini = 0.5\nsamples = 7000\nvalue = [3500.0, 3500.0]'),
#  Text(0.3523119304675119, 0.9464285714285714, 'X[6] <= 2.5\ngini = 0.421\nsamples = 4201\nvalue = [2381.918, 1026.153]'),
#  Text(0.2549883617274168, 0.9107142857142857, 'X[6] <= 1.5\ngini = 0.394\nsamples = 4117\nvalue = [2368.668, 874.398]'),
#  Text(0.14931903724247228, 0.875, 'X[1] <= 0.5\ngini = 0.474\nsamples = 2007\nvalue = [1087.795, 681.693]'),
#  Text(0.06448395404120444, 0.8392857142857143, 'X[5] <= 73493.691\ngini = 0.409\nsamples = 1041\nvalue = [594.375, 238.472]'),
#  Text(0.012834786053882725, 0.8035714285714286, 'X[4] <= 1.5\ngini = 0.495\nsamples = 260\nvalue = [135.028, 110.805]'),
#  Text(0.0071315372424722665, 0.7678571428571429, 'X[3] <= 36.5\ngini = 0.311\nsamples = 34\nvalue = [20.191, 4.818]'),
#  Text(0.005103011093502377, 0.7321428571428571, 'X[5] <= 26684.564\ngini = 0.0\nsamples = 29\nvalue = [18.298, 0.0]'),
#  Text(0.004088748019017432, 0.6964285714285714, 'gini = 0.0\nsamples = 21\nvalue = [13.25, 0.0]'),
#  Text(0.006117274167987322, 0.6964285714285714, 'gini = 0.0\nsamples = 8\nvalue = [5.048, 0.0]'),
#  Text(0.009160063391442156, 0.7321428571428571, 'X[8] <= 0.5\ngini = 0.405\nsamples = 5\nvalue = [1.893, 4.818]'),
#  Text(0.00814580031695721, 0.6964285714285714, 'X[4] <= 0.5\ngini = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.0071315372424722665, 0.6607142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.009160063391442156, 0.6607142857142857, 'gini = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.0101743264659271, 0.6964285714285714, 'gini = -0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.018538034865293186, 0.7678571428571429, 'X[3] <= 22.5\ngini = 0.499\nsamples = 226\nvalue = [114.837, 105.988]'),
#  Text(0.017523771790808242, 0.7321428571428571, 'gini = 0.0\nsamples = 9\nvalue = [5.679, 0.0]'),
#  Text(0.01955229793977813, 0.7321428571428571, 'X[3] <= 26.5\ngini = 0.5\nsamples = 217\nvalue = [109.158, 105.988]'),
#  Text(0.013217115689381933, 0.6964285714285714, 'X[9] <= 66593.92\ngini = 0.377\nsamples = 16\nvalue = [5.679, 16.862]'),
#  Text(0.011188589540412044, 0.6607142857142857, 'X[4] <= 8.5\ngini = 0.491\nsamples = 6\nvalue = [3.155, 2.409]'),
#  Text(0.0101743264659271, 0.625, 'gini = -0.0\nsamples = 5\nvalue = [3.155, 0.0]'),
#  Text(0.01220285261489699, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.015245641838351823, 0.6607142857142857, 'X[9] <= 198828.508\ngini = 0.253\nsamples = 10\nvalue = [2.524, 14.453]'),
#  Text(0.014231378763866877, 0.625, 'X[4] <= 8.0\ngini = 0.205\nsamples = 9\nvalue = [1.893, 14.453]'),
#  Text(0.013217115689381933, 0.5892857142857143, 'X[4] <= 3.5\ngini = 0.148\nsamples = 8\nvalue = [1.262, 14.453]'),
#  Text(0.01220285261489699, 0.5535714285714286, 'gini = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.014231378763866877, 0.5535714285714286, 'X[4] <= 4.5\ngini = 0.253\nsamples = 5\nvalue = [1.262, 7.226]'),
#  Text(0.013217115689381933, 0.5178571428571429, 'gini = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.015245641838351823, 0.5178571428571429, 'gini = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.015245641838351823, 0.5892857142857143, 'gini = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.016259904912836767, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.025887480190174325, 0.6964285714285714, 'X[3] <= 30.5\ngini = 0.497\nsamples = 201\nvalue = [103.479, 89.126]'),
#  Text(0.020316957210776546, 0.6607142857142857, 'X[0] <= 529.0\ngini = 0.265\nsamples = 43\nvalue = [25.87, 4.818]'),
#  Text(0.018288431061806654, 0.625, 'X[2] <= 0.5\ngini = 0.405\nsamples = 5\nvalue = [1.893, 4.818]'),
#  Text(0.01727416798732171, 0.5892857142857143, 'X[8] <= 0.5\ngini = 0.205\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.016259904912836767, 0.5535714285714286, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.018288431061806654, 0.5535714285714286, 'gini = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.0193026941362916, 0.5892857142857143, 'gini = -0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.022345483359746433, 0.625, 'X[7] <= 0.5\ngini = 0.0\nsamples = 38\nvalue = [23.977, 0.0]'),
#  Text(0.02133122028526149, 0.5892857142857143, 'gini = 0.0\nsamples = 11\nvalue = [6.941, 0.0]'),
#  Text(0.023359746434231377, 0.5892857142857143, 'gini = 0.0\nsamples = 27\nvalue = [17.036, 0.0]'),
#  Text(0.031458003169572105, 0.6607142857142857, 'X[0] <= 474.0\ngini = 0.499\nsamples = 158\nvalue = [77.61, 84.308]'),
#  Text(0.030443740095087164, 0.625, 'gini = 0.0\nsamples = 9\nvalue = [5.679, 0.0]'),
#  Text(0.03247226624405705, 0.625, 'X[9] <= 170601.062\ngini = 0.497\nsamples = 149\nvalue = [71.931, 84.308]'),
#  Text(0.02538827258320127, 0.5892857142857143, 'X[9] <= 148086.852\ngini = 0.5\nsamples = 131\nvalue = [64.99, 67.447]'),
#  Text(0.024374009508716325, 0.5535714285714286, 'X[9] <= 121182.578\ngini = 0.495\nsamples = 115\nvalue = [54.895, 67.447]'),
#  Text(0.01781299524564184, 0.5178571428571429, 'X[9] <= 79592.887\ngini = 0.5\nsamples = 96\nvalue = [48.585, 45.767]'),
#  Text(0.01179080824088748, 0.48214285714285715, 'X[4] <= 5.5\ngini = 0.489\nsamples = 65\nvalue = [30.287, 40.95]'),
#  Text(0.0065927099841521395, 0.44642857142857145, 'X[4] <= 4.5\ngini = 0.494\nsamples = 29\nvalue = [15.143, 12.044]'),
#  Text(0.004057052297939778, 0.4107142857142857, 'X[0] <= 610.0\ngini = 0.474\nsamples = 17\nvalue = [7.572, 12.044]'),
#  Text(0.002028526148969889, 0.375, 'X[9] <= 33864.194\ngini = 0.329\nsamples = 8\nvalue = [2.524, 9.635]'),
#  Text(0.0010142630744849445, 0.3392857142857143, 'gini = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.003042789223454834, 0.3392857142857143, 'X[0] <= 514.0\ngini = 0.205\nsamples = 6\nvalue = [1.262, 9.635]'),
#  Text(0.002028526148969889, 0.30357142857142855, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.004057052297939778, 0.30357142857142855, 'X[0] <= 555.0\ngini = 0.115\nsamples = 5\nvalue = [0.631, 9.635]'),
#  Text(0.003042789223454834, 0.26785714285714285, 'X[7] <= 0.5\ngini = 0.329\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.002028526148969889, 0.23214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.004057052297939778, 0.23214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.005071315372424723, 0.26785714285714285, 'gini = -0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.006085578446909668, 0.375, 'X[8] <= 0.5\ngini = 0.437\nsamples = 9\nvalue = [5.048, 2.409]'),
#  Text(0.005071315372424723, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.0070998415213946115, 0.3392857142857143, 'gini = -0.0\nsamples = 8\nvalue = [5.048, 0.0]'),
#  Text(0.0091283676703645, 0.4107142857142857, 'X[7] <= 0.5\ngini = 0.0\nsamples = 12\nvalue = [7.572, 0.0]'),
#  Text(0.008114104595879556, 0.375, 'gini = 0.0\nsamples = 5\nvalue = [3.155, 0.0]'),
#  Text(0.010142630744849446, 0.375, 'gini = 0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  Text(0.01698890649762282, 0.44642857142857145, 'X[5] <= 67067.988\ngini = 0.451\nsamples = 36\nvalue = [15.143, 28.906]'),
#  Text(0.015974643423137876, 0.4107142857142857, 'X[9] <= 49035.91\ngini = 0.431\nsamples = 33\nvalue = [13.25, 28.906]'),
#  Text(0.012171156893819335, 0.375, 'X[0] <= 608.0\ngini = 0.493\nsamples = 24\nvalue = [11.357, 14.453]'),
#  Text(0.01115689381933439, 0.3392857142857143, 'gini = 0.0\nsamples = 8\nvalue = [5.048, 0.0]'),
#  Text(0.013185419968304279, 0.3392857142857143, 'X[3] <= 38.0\ngini = 0.423\nsamples = 16\nvalue = [6.31, 14.453]'),
#  Text(0.010649762282091918, 0.30357142857142855, 'X[4] <= 9.5\ngini = 0.384\nsamples = 14\nvalue = [5.048, 14.453]'),
#  Text(0.008621236133122028, 0.26785714285714285, 'X[0] <= 761.5\ngini = 0.451\nsamples = 12\nvalue = [5.048, 9.635]'),
#  Text(0.007606973058637084, 0.23214285714285715, 'X[4] <= 8.5\ngini = 0.372\nsamples = 9\nvalue = [3.155, 9.635]'),
#  Text(0.0065927099841521395, 0.19642857142857142, 'X[9] <= 16887.995\ngini = 0.274\nsamples = 7\nvalue = [1.893, 9.635]'),
#  Text(0.005578446909667195, 0.16071428571428573, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.007606973058637084, 0.16071428571428573, 'X[3] <= 32.5\ngini = 0.205\nsamples = 6\nvalue = [1.262, 9.635]'),
#  Text(0.0065927099841521395, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.008621236133122028, 0.125, 'X[3] <= 35.0\ngini = 0.115\nsamples = 5\nvalue = [0.631, 9.635]'),
#  Text(0.007606973058637084, 0.08928571428571429, 'X[9] <= 21667.325\ngini = 0.329\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.0065927099841521395, 0.05357142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.008621236133122028, 0.05357142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.009635499207606974, 0.08928571428571429, 'gini = -0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.008621236133122028, 0.19642857142857142, 'gini = -0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.009635499207606974, 0.23214285714285715, 'gini = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.012678288431061807, 0.26785714285714285, 'X[8] <= 0.5\ngini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.011664025356576862, 0.23214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.013692551505546751, 0.23214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.01572107765451664, 0.30357142857142855, 'X[8] <= 0.5\ngini = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.014706814580031695, 0.26785714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.016735340729001586, 0.26785714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.019778129952456418, 0.375, 'X[0] <= 676.0\ngini = 0.205\nsamples = 9\nvalue = [1.893, 14.453]'),
#  Text(0.018763866877971474, 0.3392857142857143, 'X[9] <= 76641.484\ngini = 0.08\nsamples = 7\nvalue = [0.631, 14.453]'),
#  Text(0.01774960380348653, 0.30357142857142855, 'gini = 0.0\nsamples = 6\nvalue = [0.0, 14.453]'),
#  Text(0.019778129952456418, 0.30357142857142855, 'gini = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.02079239302694136, 0.3392857142857143, 'gini = -0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.018003169572107767, 0.4107142857142857, 'gini = -0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.023835182250396197, 0.48214285714285715, 'X[9] <= 111332.754\ngini = 0.33\nsamples = 31\nvalue = [18.298, 4.818]'),
#  Text(0.02180665610142631, 0.44642857142857145, 'X[2] <= 0.5\ngini = 0.0\nsamples = 22\nvalue = [13.881, 0.0]'),
#  Text(0.02079239302694136, 0.4107142857142857, 'gini = 0.0\nsamples = 13\nvalue = [8.203, 0.0]'),
#  Text(0.022820919175911253, 0.4107142857142857, 'gini = 0.0\nsamples = 9\nvalue = [5.679, 0.0]'),
#  Text(0.025863708399366084, 0.44642857142857145, 'X[9] <= 115494.098\ngini = 0.499\nsamples = 9\nvalue = [4.417, 4.818]'),
#  Text(0.02484944532488114, 0.4107142857142857, 'X[8] <= 0.5\ngini = 0.205\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.023835182250396197, 0.375, 'X[0] <= 624.5\ngini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.022820919175911253, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.02484944532488114, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.025863708399366084, 0.375, 'gini = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.026877971473851032, 0.4107142857142857, 'gini = -0.0\nsamples = 6\nvalue = [3.786, 0.0]'),
#  Text(0.030935023771790807, 0.5178571428571429, 'X[0] <= 587.5\ngini = 0.349\nsamples = 19\nvalue = [6.31, 21.679]'),
#  Text(0.029920760697305863, 0.48214285714285715, 'gini = 0.0\nsamples = 5\nvalue = [3.155, 0.0]'),
#  Text(0.03194928684627575, 0.48214285714285715, 'X[3] <= 38.5\ngini = 0.222\nsamples = 14\nvalue = [3.155, 21.679]'),
#  Text(0.029920760697305863, 0.44642857142857145, 'X[4] <= 9.0\ngini = 0.148\nsamples = 12\nvalue = [1.893, 21.679]'),
#  Text(0.02890649762282092, 0.4107142857142857, 'X[9] <= 132390.355\ngini = 0.104\nsamples = 11\nvalue = [1.262, 21.679]'),
#  Text(0.027892234548335976, 0.375, 'X[9] <= 123701.094\ngini = 0.253\nsamples = 5\nvalue = [1.262, 7.226]'),
#  Text(0.026877971473851032, 0.3392857142857143, 'gini = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.02890649762282092, 0.3392857142857143, 'gini = -0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.029920760697305863, 0.375, 'gini = 0.0\nsamples = 6\nvalue = [0.0, 14.453]'),
#  Text(0.030935023771790807, 0.4107142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.03397781299524564, 0.44642857142857145, 'X[8] <= 0.5\ngini = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.0329635499207607, 0.4107142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.034992076069730586, 0.4107142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.026402535657686212, 0.5535714285714286, 'gini = 0.0\nsamples = 16\nvalue = [10.096, 0.0]'),
#  Text(0.039556259904912836, 0.5892857142857143, 'X[9] <= 183265.359\ngini = 0.413\nsamples = 18\nvalue = [6.941, 16.862]'),
#  Text(0.037020602218700474, 0.5535714285714286, 'X[9] <= 180781.812\ngini = 0.172\nsamples = 7\nvalue = [1.262, 12.044]'),
#  Text(0.036006339144215534, 0.5178571428571429, 'X[9] <= 178967.844\ngini = 0.329\nsamples = 4\nvalue = [1.262, 4.818]'),
#  Text(0.034992076069730586, 0.48214285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.037020602218700474, 0.48214285714285715, 'X[4] <= 5.0\ngini = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.036006339144215534, 0.44642857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.03803486529318542, 0.44642857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.03803486529318542, 0.5178571428571429, 'gini = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.0420919175911252, 0.5535714285714286, 'X[9] <= 188413.625\ngini = 0.497\nsamples = 11\nvalue = [5.679, 4.818]'),
#  Text(0.04006339144215531, 0.5178571428571429, 'X[9] <= 184344.875\ngini = 0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  Text(0.03904912836767036, 0.48214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.041077654516640257, 0.48214285714285715, 'gini = 0.0\nsamples = 6\nvalue = [3.786, 0.0]'),
#  Text(0.044120443740095085, 0.5178571428571429, 'X[9] <= 198162.508\ngini = 0.329\nsamples = 4\nvalue = [1.262, 4.818]'),
#  Text(0.043106180665610144, 0.48214285714285715, 'X[2] <= 0.5\ngini = 0.205\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.0420919175911252, 0.44642857142857145, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.044120443740095085, 0.44642857142857145, 'gini = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.04513470681458003, 0.48214285714285715, 'gini = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.11613312202852615, 0.8035714285714286, 'X[5] <= 178072.172\ngini = 0.34\nsamples = 781\nvalue = [459.347, 127.667]'),
#  Text(0.09229793977812996, 0.7678571428571429, 'X[3] <= 35.5\ngini = 0.305\nsamples = 754\nvalue = [448.621, 103.579]'),
#  Text(0.06960380348652932, 0.7321428571428571, 'X[9] <= 149480.711\ngini = 0.257\nsamples = 538\nvalue = [324.319, 57.811]'),
#  Text(0.059587955625990494, 0.6964285714285714, 'X[9] <= 68459.793\ngini = 0.202\nsamples = 399\nvalue = [243.555, 31.315]'),
#  Text(0.05324881141045959, 0.6607142857142857, 'X[9] <= 48683.225\ngini = 0.269\nsamples = 210\nvalue = [126.194, 24.088]'),
#  Text(0.04817749603803487, 0.625, 'X[5] <= 146036.797\ngini = 0.141\nsamples = 142\nvalue = [87.705, 7.226]'),
#  Text(0.04716323296354992, 0.5892857142857143, 'gini = -0.0\nsamples = 114\nvalue = [71.931, 0.0]'),
#  Text(0.04919175911251981, 0.5892857142857143, 'X[5] <= 158413.664\ngini = 0.431\nsamples = 28\nvalue = [15.774, 7.226]'),
#  Text(0.04716323296354992, 0.5535714285714286, 'X[9] <= 19516.13\ngini = 0.5\nsamples = 14\nvalue = [6.941, 7.226]'),
#  Text(0.04614896988906498, 0.5178571428571429, 'gini = 0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  Text(0.04817749603803487, 0.5178571428571429, 'X[0] <= 622.0\ngini = 0.384\nsamples = 7\nvalue = [2.524, 7.226]'),
#  Text(0.04716323296354992, 0.48214285714285715, 'X[5] <= 148076.688\ngini = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.04614896988906498, 0.44642857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.04817749603803487, 0.44642857142857145, 'gini = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.04919175911251981, 0.48214285714285715, 'gini = -0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.0512202852614897, 0.5535714285714286, 'X[8] <= 0.5\ngini = 0.0\nsamples = 14\nvalue = [8.834, 0.0]'),
#  Text(0.050206022187004755, 0.5178571428571429, 'gini = 0.0\nsamples = 8\nvalue = [5.048, 0.0]'),
#  Text(0.05223454833597464, 0.5178571428571429, 'gini = 0.0\nsamples = 6\nvalue = [3.786, 0.0]'),
#  Text(0.05832012678288431, 0.625, 'X[3] <= 23.0\ngini = 0.424\nsamples = 68\nvalue = [38.489, 16.862]'),
#  Text(0.05629160063391442, 0.5892857142857143, 'X[2] <= 0.5\ngini = 0.205\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.05527733755942948, 0.5535714285714286, 'X[9] <= 60138.93\ngini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.05426307448494453, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.05629160063391442, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.057305863708399365, 0.5535714285714286, 'gini = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.0603486529318542, 0.5892857142857143, 'X[9] <= 49103.17\ngini = 0.366\nsamples = 65\nvalue = [37.858, 12.044]'),
#  Text(0.05933438985736925, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.06136291600633914, 0.5535714285714286, 'X[9] <= 56883.07\ngini = 0.323\nsamples = 64\nvalue = [37.858, 9.635]'),
#  Text(0.0603486529318542, 0.5178571428571429, 'gini = 0.0\nsamples = 26\nvalue = [16.405, 0.0]'),
#  Text(0.06237717908082409, 0.5178571428571429, 'X[3] <= 31.5\ngini = 0.428\nsamples = 38\nvalue = [21.453, 9.635]'),
#  Text(0.0603486529318542, 0.48214285714285715, 'X[4] <= 2.5\ngini = 0.5\nsamples = 19\nvalue = [9.465, 9.635]'),
#  Text(0.05933438985736925, 0.44642857142857145, 'gini = 0.0\nsamples = 6\nvalue = [3.786, 0.0]'),
#  Text(0.06136291600633914, 0.44642857142857145, 'X[4] <= 6.5\ngini = 0.467\nsamples = 13\nvalue = [5.679, 9.635]'),
#  Text(0.0603486529318542, 0.4107142857142857, 'X[0] <= 691.5\ngini = 0.329\nsamples = 8\nvalue = [2.524, 9.635]'),
#  Text(0.05933438985736925, 0.375, 'X[5] <= 109251.93\ngini = 0.115\nsamples = 5\nvalue = [0.631, 9.635]'),
#  Text(0.05832012678288431, 0.3392857142857143, 'X[7] <= 0.5\ngini = 0.329\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.057305863708399365, 0.30357142857142855, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.05933438985736925, 0.30357142857142855, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.0603486529318542, 0.3392857142857143, 'gini = -0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.06136291600633914, 0.375, 'gini = -0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.06237717908082409, 0.4107142857142857, 'gini = 0.0\nsamples = 5\nvalue = [3.155, 0.0]'),
#  Text(0.06440570522979398, 0.48214285714285715, 'X[5] <= 80220.602\ngini = 0.0\nsamples = 19\nvalue = [11.988, 0.0]'),
#  Text(0.06339144215530904, 0.44642857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.06541996830427892, 0.44642857142857145, 'gini = 0.0\nsamples = 18\nvalue = [11.357, 0.0]'),
#  Text(0.0659270998415214, 0.6607142857142857, 'X[0] <= 447.5\ngini = 0.109\nsamples = 189\nvalue = [117.361, 7.226]'),
#  Text(0.06339144215530904, 0.625, 'X[9] <= 125610.703\ngini = 0.5\nsamples = 5\nvalue = [2.524, 2.409]'),
#  Text(0.06237717908082409, 0.5892857142857143, 'gini = -0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.06440570522979398, 0.5892857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.06846275752773376, 0.625, 'X[4] <= 0.5\ngini = 0.077\nsamples = 184\nvalue = [114.837, 4.818]'),
#  Text(0.06643423137876386, 0.5892857142857143, 'X[0] <= 561.0\ngini = 0.457\nsamples = 8\nvalue = [4.417, 2.409]'),
#  Text(0.06541996830427892, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.06744849445324881, 0.5535714285714286, 'gini = -0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  Text(0.07049128367670364, 0.5892857142857143, 'X[5] <= 82991.57\ngini = 0.042\nsamples = 176\nvalue = [110.42, 2.409]'),
#  Text(0.0694770206022187, 0.5535714285714286, 'X[5] <= 82838.281\ngini = 0.437\nsamples = 9\nvalue = [5.048, 2.409]'),
#  Text(0.06846275752773376, 0.5178571428571429, 'X[3] <= 19.0\ngini = 0.0\nsamples = 8\nvalue = [5.048, 0.0]'),
#  Text(0.06744849445324881, 0.48214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.0694770206022187, 0.48214285714285715, 'gini = 0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  Text(0.07049128367670364, 0.5178571428571429, 'gini = -0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.07150554675118859, 0.5535714285714286, 'gini = -0.0\nsamples = 167\nvalue = [105.372, 0.0]'),
#  Text(0.07961965134706815, 0.6964285714285714, 'X[9] <= 155243.102\ngini = 0.372\nsamples = 139\nvalue = [80.764, 26.497]'),
#  Text(0.07454833597464343, 0.6607142857142857, 'X[2] <= 0.5\ngini = 0.474\nsamples = 17\nvalue = [7.572, 12.044]'),
#  Text(0.07353407290015848, 0.625, 'gini = 0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  Text(0.07556259904912836, 0.625, 'X[5] <= 152855.32\ngini = 0.329\nsamples = 10\nvalue = [3.155, 12.044]'),
#  Text(0.07454833597464343, 0.5892857142857143, 'X[3] <= 33.5\ngini = 0.235\nsamples = 8\nvalue = [1.893, 12.044]'),
#  Text(0.07353407290015848, 0.5535714285714286, 'X[3] <= 21.0\ngini = 0.172\nsamples = 7\nvalue = [1.262, 12.044]'),
#  Text(0.07251980982567353, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.07454833597464343, 0.5178571428571429, 'X[5] <= 116751.785\ngini = 0.095\nsamples = 6\nvalue = [0.631, 12.044]'),
#  Text(0.07353407290015848, 0.48214285714285715, 'X[4] <= 0.5\ngini = 0.329\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.07251980982567353, 0.44642857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.07454833597464343, 0.44642857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.07556259904912836, 0.48214285714285715, 'gini = -0.0\nsamples = 4\nvalue = [0.0, 9.635]'),
#  Text(0.07556259904912836, 0.5535714285714286, 'gini = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.07657686212361331, 0.5892857142857143, 'gini = -0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.08469096671949287, 0.6607142857142857, 'X[9] <= 187911.906\ngini = 0.275\nsamples = 122\nvalue = [73.193, 14.453]'),
#  Text(0.08063391442155309, 0.625, 'X[9] <= 164239.695\ngini = 0.157\nsamples = 83\nvalue = [51.109, 4.818]'),
#  Text(0.07961965134706815, 0.5892857142857143, 'X[9] <= 163611.656\ngini = 0.391\nsamples = 23\nvalue = [13.25, 4.818]'),
#  Text(0.07759112519809826, 0.5535714285714286, 'X[0] <= 487.5\ngini = 0.0\nsamples = 19\nvalue = [11.988, 0.0]'),
#  Text(0.07657686212361331, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.0786053882725832, 0.5178571428571429, 'gini = 0.0\nsamples = 18\nvalue = [11.357, 0.0]'),
#  Text(0.08164817749603803, 0.5535714285714286, 'X[4] <= 2.5\ngini = 0.329\nsamples = 4\nvalue = [1.262, 4.818]'),
#  Text(0.08063391442155309, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.08266244057052298, 0.5178571428571429, 'X[8] <= 0.5\ngini = 0.205\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.08164817749603803, 0.48214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.08367670364500793, 0.48214285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.08164817749603803, 0.5892857142857143, 'gini = -0.0\nsamples = 60\nvalue = [37.858, 0.0]'),
#  Text(0.08874801901743265, 0.625, 'X[3] <= 31.5\ngini = 0.423\nsamples = 39\nvalue = [22.084, 9.635]'),
#  Text(0.0877337559429477, 0.5892857142857143, 'gini = 0.0\nsamples = 19\nvalue = [11.988, 0.0]'),
#  Text(0.0897622820919176, 0.5892857142857143, 'X[3] <= 33.5\ngini = 0.5\nsamples = 20\nvalue = [10.096, 9.635]'),
#  Text(0.0877337559429477, 0.5535714285714286, 'X[9] <= 197918.445\ngini = 0.451\nsamples = 12\nvalue = [5.048, 9.635]'),
#  Text(0.08671949286846276, 0.5178571428571429, 'X[4] <= 9.5\ngini = 0.329\nsamples = 8\nvalue = [2.524, 9.635]'),
#  Text(0.08570522979397781, 0.48214285714285715, 'X[8] <= 0.5\ngini = 0.205\nsamples = 6\nvalue = [1.262, 9.635]'),
#  Text(0.08469096671949287, 0.44642857142857145, 'X[0] <= 677.5\ngini = 0.115\nsamples = 5\nvalue = [0.631, 9.635]'),
#  Text(0.08367670364500793, 0.4107142857142857, 'gini = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.08570522979397781, 0.4107142857142857, 'X[7] <= 0.5\ngini = 0.329\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.08469096671949287, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.08671949286846276, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.08671949286846276, 0.44642857142857145, 'gini = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.0877337559429477, 0.48214285714285715, 'gini = -0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.08874801901743265, 0.5178571428571429, 'gini = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.09179080824088748, 0.5535714285714286, 'X[3] <= 34.5\ngini = 0.0\nsamples = 8\nvalue = [5.048, 0.0]'),
#  Text(0.09077654516640253, 0.5178571428571429, 'gini = 0.0\nsamples = 5\nvalue = [3.155, 0.0]'),
#  Text(0.09280507131537243, 0.5178571428571429, 'gini = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.11499207606973058, 0.7321428571428571, 'X[0] <= 747.0\ngini = 0.393\nsamples = 216\nvalue = [124.301, 45.767]'),
#  Text(0.10396196513470682, 0.6964285714285714, 'X[9] <= 168130.734\ngini = 0.337\nsamples = 165\nvalue = [97.17, 26.497]'),
#  Text(0.09736925515055468, 0.6607142857142857, 'X[9] <= 22130.325\ngini = 0.223\nsamples = 135\nvalue = [82.026, 12.044]'),
#  Text(0.09381933438985737, 0.625, 'X[4] <= 1.5\ngini = 0.493\nsamples = 12\nvalue = [5.679, 7.226]'),
#  Text(0.09280507131537243, 0.5892857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.09483359746434232, 0.5892857142857143, 'X[0] <= 515.0\ngini = 0.418\nsamples = 10\nvalue = [5.679, 2.409]'),
#  Text(0.09381933438985737, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.09584786053882725, 0.5535714285714286, 'gini = 0.0\nsamples = 9\nvalue = [5.679, 0.0]'),
#  Text(0.10091917591125198, 0.625, 'X[4] <= 9.5\ngini = 0.112\nsamples = 123\nvalue = [76.348, 4.818]'),
#  Text(0.0988906497622821, 0.5892857142857143, 'X[5] <= 96905.41\ngini = 0.063\nsamples = 114\nvalue = [71.3, 2.409]'),
#  Text(0.09787638668779715, 0.5535714285714286, 'X[5] <= 96566.336\ngini = 0.3\nsamples = 18\nvalue = [10.727, 2.409]'),
#  Text(0.0968621236133122, 0.5178571428571429, 'gini = 0.0\nsamples = 17\nvalue = [10.727, 0.0]'),
#  Text(0.0988906497622821, 0.5178571428571429, 'gini = -0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.09990491283676704, 0.5535714285714286, 'gini = -0.0\nsamples = 96\nvalue = [60.573, 0.0]'),
#  Text(0.10294770206022187, 0.5892857142857143, 'X[0] <= 678.0\ngini = 0.437\nsamples = 9\nvalue = [5.048, 2.409]'),
#  Text(0.10193343898573692, 0.5535714285714286, 'gini = -0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  Text(0.10396196513470682, 0.5535714285714286, 'X[0] <= 687.0\ngini = 0.329\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.10294770206022187, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.10497622820919177, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.11055467511885896, 0.6607142857142857, 'X[5] <= 94833.801\ngini = 0.5\nsamples = 30\nvalue = [15.143, 14.453]'),
#  Text(0.1080190174326466, 0.625, 'X[3] <= 38.0\ngini = 0.329\nsamples = 8\nvalue = [2.524, 9.635]'),
#  Text(0.10700475435816165, 0.5892857142857143, 'X[0] <= 677.5\ngini = 0.205\nsamples = 6\nvalue = [1.262, 9.635]'),
#  Text(0.1059904912836767, 0.5535714285714286, 'gini = 0.0\nsamples = 4\nvalue = [0.0, 9.635]'),
#  Text(0.1080190174326466, 0.5535714285714286, 'gini = -0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.10903328050713154, 0.5892857142857143, 'gini = -0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.11309033280507132, 0.625, 'X[0] <= 607.5\ngini = 0.4\nsamples = 22\nvalue = [12.619, 4.818]'),
#  Text(0.11207606973058637, 0.5892857142857143, 'X[5] <= 118488.508\ngini = 0.499\nsamples = 9\nvalue = [4.417, 4.818]'),
#  Text(0.11004754358161647, 0.5535714285714286, 'X[5] <= 102214.418\ngini = 0.0\nsamples = 5\nvalue = [3.155, 0.0]'),
#  Text(0.10903328050713154, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.11106180665610142, 0.5178571428571429, 'gini = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.11410459587955626, 0.5535714285714286, 'X[2] <= 0.5\ngini = 0.329\nsamples = 4\nvalue = [1.262, 4.818]'),
#  Text(0.11309033280507132, 0.5178571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.1151188589540412, 0.5178571428571429, 'X[3] <= 37.0\ngini = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.11410459587955626, 0.48214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.11613312202852615, 0.48214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.11410459587955626, 0.5892857142857143, 'gini = 0.0\nsamples = 13\nvalue = [8.203, 0.0]'),
#  Text(0.12602218700475437, 0.6964285714285714, 'X[9] <= 91330.332\ngini = 0.486\nsamples = 51\nvalue = [27.132, 19.27]'),
#  Text(0.12171156893819335, 0.6607142857142857, 'X[5] <= 99791.629\ngini = 0.451\nsamples = 21\nvalue = [8.834, 16.862]'),
#  Text(0.1206973058637084, 0.625, 'gini = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.12272583201267828, 0.625, 'X[0] <= 840.0\ngini = 0.413\nsamples = 18\nvalue = [6.941, 16.862]'),
#  Text(0.12019017432646592, 0.5892857142857143, 'X[0] <= 808.5\ngini = 0.377\nsamples = 16\nvalue = [5.679, 16.862]'),
#  Text(0.11816164817749604, 0.5535714285714286, 'X[9] <= 43630.738\ngini = 0.467\nsamples = 13\nvalue = [5.679, 9.635]'),
#  Text(0.11714738510301109, 0.5178571428571429, 'gini = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.11917591125198099, 0.5178571428571429, 'X[0] <= 787.0\ngini = 0.431\nsamples = 11\nvalue = [4.417, 9.635]'),
#  Text(0.11816164817749604, 0.48214285714285715, 'X[9] <= 59305.215\ngini = 0.372\nsamples = 9\nvalue = [3.155, 9.635]'),
#  Text(0.11613312202852615, 0.44642857142857145, 'X[4] <= 6.5\ngini = 0.493\nsamples = 4\nvalue = [1.893, 2.409]'),
#  Text(0.1151188589540412, 0.4107142857142857, 'gini = -0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.11714738510301109, 0.4107142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.12019017432646592, 0.44642857142857145, 'X[3] <= 37.0\ngini = 0.253\nsamples = 5\nvalue = [1.262, 7.226]'),
#  Text(0.11917591125198099, 0.4107142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.12120443740095087, 0.4107142857142857, 'X[8] <= 0.5\ngini = 0.148\nsamples = 4\nvalue = [0.631, 7.226]'),
#  Text(0.12019017432646592, 0.375, 'X[4] <= 7.5\ngini = 0.329\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.11917591125198099, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.12120443740095087, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.12221870047543582, 0.375, 'gini = -0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.12019017432646592, 0.48214285714285715, 'gini = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.12221870047543582, 0.5535714285714286, 'X[4] <= 4.5\ngini = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.12120443740095087, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.12323296354992076, 0.5178571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.12526148969889064, 0.5892857142857143, 'X[4] <= 3.0\ngini = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.12424722662440571, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.1262757527733756, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.13033280507131537, 0.6607142857142857, 'X[3] <= 38.5\ngini = 0.206\nsamples = 30\nvalue = [18.298, 2.409]'),
#  Text(0.12830427892234547, 0.625, 'X[5] <= 83565.965\ngini = 0.0\nsamples = 24\nvalue = [15.143, 0.0]'),
#  Text(0.12729001584786054, 0.5892857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.12931854199683043, 0.5892857142857143, 'gini = 0.0\nsamples = 23\nvalue = [14.512, 0.0]'),
#  Text(0.13236133122028526, 0.625, 'X[4] <= 1.5\ngini = 0.491\nsamples = 6\nvalue = [3.155, 2.409]'),
#  Text(0.13134706814580033, 0.5892857142857143, 'X[0] <= 817.5\ngini = 0.329\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.13033280507131537, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.13236133122028526, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.1333755942947702, 0.5892857142857143, 'gini = -0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.13996830427892235, 0.7678571428571429, 'X[0] <= 635.0\ngini = 0.426\nsamples = 27\nvalue = [10.727, 24.088]'),
#  Text(0.1354041204437401, 0.7321428571428571, 'X[2] <= 0.5\ngini = 0.491\nsamples = 12\nvalue = [6.31, 4.818]'),
#  Text(0.1333755942947702, 0.6964285714285714, 'X[7] <= 0.5\ngini = 0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  Text(0.13236133122028526, 0.6607142857142857, 'gini = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.13438985736925516, 0.6607142857142857, 'gini = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.13743264659270998, 0.6964285714285714, 'X[4] <= 1.5\ngini = 0.405\nsamples = 5\nvalue = [1.893, 4.818]'),
#  Text(0.13641838351822505, 0.6607142857142857, 'gini = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.13844690966719492, 0.6607142857142857, 'X[4] <= 5.0\ngini = 0.205\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.13743264659270998, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.13946117274167988, 0.625, 'gini = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.1445324881141046, 0.7321428571428571, 'X[8] <= 0.5\ngini = 0.303\nsamples = 15\nvalue = [4.417, 19.27]'),
#  Text(0.14148969889064977, 0.6964285714285714, 'X[9] <= 25046.199\ngini = 0.148\nsamples = 8\nvalue = [1.262, 14.453]'),
#  Text(0.1404754358161648, 0.6607142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.1425039619651347, 0.6607142857142857, 'X[3] <= 37.0\ngini = 0.08\nsamples = 7\nvalue = [0.631, 14.453]'),
#  Text(0.14148969889064977, 0.625, 'gini = 0.0\nsamples = 5\nvalue = [0.0, 12.044]'),
#  Text(0.14351822503961964, 0.625, 'X[5] <= 180325.648\ngini = 0.329\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.1425039619651347, 0.5892857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.1445324881141046, 0.5892857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.14757527733755943, 0.6964285714285714, 'X[5] <= 188001.133\ngini = 0.478\nsamples = 7\nvalue = [3.155, 4.818]'),
#  Text(0.1465610142630745, 0.6607142857142857, 'X[2] <= 0.5\ngini = 0.205\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.14554675118858953, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.14757527733755943, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.14858954041204436, 0.6607142857142857, 'gini = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.2341541204437401, 0.8392857142857143, 'X[8] <= 0.5\ngini = 0.499\nsamples = 966\nvalue = [493.42, 443.221]'),
#  Text(0.17748019017432645, 0.8035714285714286, 'X[0] <= 509.5\ngini = 0.492\nsamples = 474\nvalue = [223.995, 286.648]'),
#  Text(0.15264659270998415, 0.7678571428571429, 'X[4] <= 0.5\ngini = 0.311\nsamples = 34\nvalue = [20.191, 4.818]'),
#  Text(0.15163232963549922, 0.7321428571428571, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.15366085578446909, 0.7321428571428571, 'X[4] <= 8.5\ngini = 0.19\nsamples = 33\nvalue = [20.191, 2.409]'),
#  Text(0.15163232963549922, 0.6964285714285714, 'X[1] <= 1.5\ngini = 0.0\nsamples = 30\nvalue = [18.929, 0.0]'),
#  Text(0.15061806656101426, 0.6607142857142857, 'gini = 0.0\nsamples = 17\nvalue = [10.727, 0.0]'),
#  Text(0.15264659270998415, 0.6607142857142857, 'gini = 0.0\nsamples = 13\nvalue = [8.203, 0.0]'),
#  Text(0.15568938193343898, 0.6964285714285714, 'X[3] <= 36.0\ngini = 0.451\nsamples = 3\nvalue = [1.262, 2.409]'),
#  Text(0.15467511885895405, 0.6607142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.15670364500792394, 0.6607142857142857, 'gini = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.20231378763866878, 0.7678571428571429, 'X[2] <= 0.5\ngini = 0.487\nsamples = 440\nvalue = [203.804, 281.831]'),
#  Text(0.17759112519809825, 0.7321428571428571, 'X[0] <= 632.5\ngini = 0.5\nsamples = 240\nvalue = [120.516, 118.032]'),
#  Text(0.16266244057052298, 0.6964285714285714, 'X[9] <= 113453.156\ngini = 0.466\nsamples = 94\nvalue = [41.013, 69.855]'),
#  Text(0.1587321711568938, 0.6607142857142857, 'X[5] <= 160560.727\ngini = 0.4\nsamples = 59\nvalue = [22.084, 57.811]'),
#  Text(0.15771790808240888, 0.625, 'X[7] <= 0.5\ngini = 0.359\nsamples = 52\nvalue = [17.667, 57.811]'),
#  Text(0.15239302694136292, 0.5892857142857143, 'X[9] <= 57657.164\ngini = 0.493\nsamples = 16\nvalue = [7.572, 9.635]'),
#  Text(0.15137876386687796, 0.5535714285714286, 'gini = 0.0\nsamples = 8\nvalue = [5.048, 0.0]'),
#  Text(0.15340729001584785, 0.5535714285714286, 'X[4] <= 3.5\ngini = 0.329\nsamples = 8\nvalue = [2.524, 9.635]'),
#  Text(0.15239302694136292, 0.5178571428571429, 'gini = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.1544215530903328, 0.5178571428571429, 'X[0] <= 528.0\ngini = 0.205\nsamples = 6\nvalue = [1.262, 9.635]'),
#  Text(0.15340729001584785, 0.48214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.15543581616481775, 0.48214285714285715, 'X[3] <= 35.5\ngini = 0.115\nsamples = 5\nvalue = [0.631, 9.635]'),
#  Text(0.1544215530903328, 0.44642857142857145, 'X[5] <= 136431.031\ngini = 0.329\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.15340729001584785, 0.4107142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.15543581616481775, 0.4107142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.15645007923930268, 0.44642857142857145, 'gini = -0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.16304278922345483, 0.5892857142857143, 'X[5] <= 132136.402\ngini = 0.286\nsamples = 36\nvalue = [10.096, 48.176]'),
#  Text(0.16050713153724247, 0.5535714285714286, 'X[0] <= 571.5\ngini = 0.379\nsamples = 23\nvalue = [8.203, 24.088]'),
#  Text(0.15949286846275754, 0.5178571428571429, 'gini = 0.0\nsamples = 6\nvalue = [3.786, 0.0]'),
#  Text(0.1615213946117274, 0.5178571428571429, 'X[5] <= 115863.625\ngini = 0.262\nsamples = 17\nvalue = [4.417, 24.088]'),
#  Text(0.15949286846275754, 0.48214285714285715, 'X[5] <= 86252.184\ngini = 0.135\nsamples = 13\nvalue = [1.893, 24.088]'),
#  Text(0.15847860538827258, 0.44642857142857145, 'gini = 0.0\nsamples = 8\nvalue = [0.0, 19.27]'),
#  Text(0.16050713153724247, 0.44642857142857145, 'X[5] <= 108323.301\ngini = 0.405\nsamples = 5\nvalue = [1.893, 4.818]'),
#  Text(0.15949286846275754, 0.4107142857142857, 'X[3] <= 34.5\ngini = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.15847860538827258, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.16050713153724247, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.1615213946117274, 0.4107142857142857, 'gini = -0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.1635499207606973, 0.48214285714285715, 'X[1] <= 1.5\ngini = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.16253565768621236, 0.44642857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.16456418383518226, 0.44642857142857145, 'gini = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.1655784469096672, 0.5535714285714286, 'X[9] <= 2274.275\ngini = 0.135\nsamples = 13\nvalue = [1.893, 24.088]'),
#  Text(0.16456418383518226, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.16659270998415213, 0.5178571428571429, 'X[5] <= 152488.5\ngini = 0.095\nsamples = 12\nvalue = [1.262, 24.088]'),
#  Text(0.1655784469096672, 0.48214285714285715, 'gini = -0.0\nsamples = 8\nvalue = [0.0, 19.27]'),
#  Text(0.1676069730586371, 0.48214285714285715, 'X[5] <= 157381.148\ngini = 0.329\nsamples = 4\nvalue = [1.262, 4.818]'),
#  Text(0.16659270998415213, 0.44642857142857145, 'gini = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.16862123613312202, 0.44642857142857145, 'X[0] <= 572.0\ngini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.1676069730586371, 0.4107142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.16963549920760698, 0.4107142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.15974643423137877, 0.625, 'gini = -0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  Text(0.16659270998415213, 0.6607142857142857, 'X[5] <= 121337.277\ngini = 0.475\nsamples = 35\nvalue = [18.929, 12.044]'),
#  Text(0.1655784469096672, 0.625, 'gini = -0.0\nsamples = 20\nvalue = [12.619, 0.0]'),
#  Text(0.1676069730586371, 0.625, 'X[5] <= 128842.766\ngini = 0.451\nsamples = 15\nvalue = [6.31, 12.044]'),
#  Text(0.16659270998415213, 0.5892857142857143, 'gini = 0.0\nsamples = 5\nvalue = [0.0, 12.044]'),
#  Text(0.16862123613312202, 0.5892857142857143, 'X[0] <= 537.0\ngini = 0.0\nsamples = 10\nvalue = [6.31, 0.0]'),
#  Text(0.1676069730586371, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.16963549920760698, 0.5535714285714286, 'gini = 0.0\nsamples = 9\nvalue = [5.679, 0.0]'),
#  Text(0.19251980982567354, 0.6964285714285714, 'X[9] <= 164340.555\ngini = 0.47\nsamples = 146\nvalue = [79.502, 48.176]'),
#  Text(0.18345483359746434, 0.6607142857142857, 'X[5] <= 101965.473\ngini = 0.415\nsamples = 122\nvalue = [69.407, 28.906]'),
#  Text(0.1824405705229794, 0.625, 'gini = 0.0\nsamples = 37\nvalue = [23.346, 0.0]'),
#  Text(0.18446909667194927, 0.625, 'X[5] <= 121953.625\ngini = 0.474\nsamples = 85\nvalue = [46.061, 28.906]'),
#  Text(0.18003169572107766, 0.5892857142857143, 'X[9] <= 133519.832\ngini = 0.478\nsamples = 28\nvalue = [12.619, 19.27]'),
#  Text(0.17724247226624407, 0.5535714285714286, 'X[5] <= 121604.609\ngini = 0.451\nsamples = 24\nvalue = [10.096, 19.27]'),
#  Text(0.1747068145800317, 0.5178571428571429, 'X[9] <= 97871.348\ngini = 0.484\nsamples = 22\nvalue = [10.096, 14.453]'),
#  Text(0.1726782884310618, 0.48214285714285715, 'X[3] <= 29.5\ngini = 0.451\nsamples = 18\nvalue = [7.572, 14.453]'),
#  Text(0.17166402535657685, 0.44642857142857145, 'gini = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.17369255150554674, 0.44642857142857145, 'X[4] <= 2.5\ngini = 0.423\nsamples = 16\nvalue = [6.31, 14.453]'),
#  Text(0.17166402535657685, 0.4107142857142857, 'X[9] <= 16135.545\ngini = 0.491\nsamples = 6\nvalue = [3.155, 2.409]'),
#  Text(0.17064976228209192, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.1726782884310618, 0.375, 'gini = -0.0\nsamples = 5\nvalue = [3.155, 0.0]'),
#  Text(0.17572107765451664, 0.4107142857142857, 'X[3] <= 31.0\ngini = 0.329\nsamples = 10\nvalue = [3.155, 12.044]'),
#  Text(0.1747068145800317, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.17673534072900157, 0.375, 'X[9] <= 12929.06\ngini = 0.235\nsamples = 8\nvalue = [1.893, 12.044]'),
#  Text(0.17572107765451664, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.17774960380348653, 0.3392857142857143, 'X[5] <= 111741.504\ngini = 0.172\nsamples = 7\nvalue = [1.262, 12.044]'),
#  Text(0.17673534072900157, 0.30357142857142855, 'gini = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.17876386687797147, 0.30357142857142855, 'X[5] <= 113467.844\ngini = 0.329\nsamples = 4\nvalue = [1.262, 4.818]'),
#  Text(0.17774960380348653, 0.26785714285714285, 'gini = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.17977812995245643, 0.26785714285714285, 'X[4] <= 6.0\ngini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.17876386687797147, 0.23214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.18079239302694136, 0.23214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.17673534072900157, 0.48214285714285715, 'X[3] <= 28.0\ngini = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.17572107765451664, 0.44642857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.17774960380348653, 0.44642857142857145, 'gini = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.17977812995245643, 0.5178571428571429, 'X[5] <= 121785.941\ngini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.17876386687797147, 0.48214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.18079239302694136, 0.48214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.18282091917591126, 0.5535714285714286, 'X[0] <= 667.0\ngini = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.1818066561014263, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.1838351822503962, 0.5178571428571429, 'gini = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.1889064976228209, 0.5892857142857143, 'X[0] <= 800.0\ngini = 0.347\nsamples = 57\nvalue = [33.441, 9.635]'),
#  Text(0.18687797147385102, 0.5535714285714286, 'X[9] <= 78036.578\ngini = 0.233\nsamples = 51\nvalue = [30.918, 4.818]'),
#  Text(0.18586370839936608, 0.5178571428571429, 'X[9] <= 62154.658\ngini = 0.409\nsamples = 21\nvalue = [11.988, 4.818]'),
#  Text(0.18484944532488115, 0.48214285714285715, 'gini = 0.0\nsamples = 17\nvalue = [10.727, 0.0]'),
#  Text(0.18687797147385102, 0.48214285714285715, 'X[3] <= 36.5\ngini = 0.329\nsamples = 4\nvalue = [1.262, 4.818]'),
#  Text(0.18586370839936608, 0.44642857142857145, 'X[5] <= 166191.68\ngini = 0.205\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.18484944532488115, 0.4107142857142857, 'X[0] <= 697.5\ngini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.1838351822503962, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.18586370839936608, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.18687797147385102, 0.4107142857142857, 'gini = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.18789223454833598, 0.44642857142857145, 'gini = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.18789223454833598, 0.5178571428571429, 'gini = -0.0\nsamples = 30\nvalue = [18.929, 0.0]'),
#  Text(0.1909350237717908, 0.5535714285714286, 'X[5] <= 147364.438\ngini = 0.451\nsamples = 6\nvalue = [2.524, 4.818]'),
#  Text(0.18992076069730587, 0.5178571428571429, 'gini = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.19194928684627574, 0.5178571428571429, 'X[1] <= 1.5\ngini = 0.205\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.1909350237717908, 0.48214285714285715, 'X[9] <= 72868.539\ngini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.18992076069730587, 0.44642857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.19194928684627574, 0.44642857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.1929635499207607, 0.48214285714285715, 'gini = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.20158478605388272, 0.6607142857142857, 'X[9] <= 189847.664\ngini = 0.451\nsamples = 24\nvalue = [10.096, 19.27]'),
#  Text(0.19955625990491282, 0.625, 'X[0] <= 653.0\ngini = 0.389\nsamples = 19\nvalue = [6.941, 19.27]'),
#  Text(0.1985419968304279, 0.5892857142857143, 'gini = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.2005705229793978, 0.5892857142857143, 'X[0] <= 767.5\ngini = 0.303\nsamples = 15\nvalue = [4.417, 19.27]'),
#  Text(0.19803486529318542, 0.5535714285714286, 'X[3] <= 38.5\ngini = 0.242\nsamples = 13\nvalue = [3.155, 19.27]'),
#  Text(0.19600633914421553, 0.5178571428571429, 'X[4] <= 9.5\ngini = 0.163\nsamples = 11\nvalue = [1.893, 19.27]'),
#  Text(0.1949920760697306, 0.48214285714285715, 'X[5] <= 109132.969\ngini = 0.115\nsamples = 10\nvalue = [1.262, 19.27]'),
#  Text(0.19397781299524564, 0.44642857142857145, 'X[5] <= 97302.395\ngini = 0.329\nsamples = 4\nvalue = [1.262, 4.818]'),
# ...
#  Text(0.3445324881141046, 0.26785714285714285, 'gini = -0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.3455467511885895, 0.375, 'X[5] <= 27049.09\ngini = 0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  Text(0.3445324881141046, 0.3392857142857143, 'gini = 0.0\nsamples = 6\nvalue = [3.786, 0.0]'),
#  Text(0.3465610142630745, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.3445324881141046, 0.44642857142857145, 'gini = -0.0\nsamples = 50\nvalue = [31.549, 0.0]'),
#  Text(0.3496038034865293, 0.48214285714285715, 'X[4] <= 6.0\ngini = 0.481\nsamples = 20\nvalue = [10.727, 7.226]'),
#  Text(0.34757527733755944, 0.44642857142857145, 'X[7] <= 0.5\ngini = 0.0\nsamples = 11\nvalue = [6.941, 0.0]'),
#  Text(0.3465610142630745, 0.4107142857142857, 'gini = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.3485895404120444, 0.4107142857142857, 'gini = 0.0\nsamples = 8\nvalue = [5.048, 0.0]'),
#  Text(0.35163232963549923, 0.44642857142857145, 'X[1] <= 1.5\ngini = 0.451\nsamples = 9\nvalue = [3.786, 7.226]'),
#  Text(0.35061806656101424, 0.4107142857142857, 'X[0] <= 594.5\ngini = 0.475\nsamples = 7\nvalue = [3.786, 2.409]'),
#  Text(0.3496038034865293, 0.375, 'X[1] <= 0.5\ngini = 0.329\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.3485895404120444, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.35061806656101424, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.35163232963549923, 0.375, 'gini = -0.0\nsamples = 5\nvalue = [3.155, 0.0]'),
#  Text(0.35264659270998416, 0.4107142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.3485895404120444, 0.5178571428571429, 'gini = -0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.3496038034865293, 0.5535714285714286, 'gini = 0.0\nsamples = 28\nvalue = [17.667, 0.0]'),
#  Text(0.33702060221870045, 0.6964285714285714, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.36038034865293184, 0.7321428571428571, 'X[0] <= 779.5\ngini = 0.067\nsamples = 747\nvalue = [466.919, 16.862]'),
#  Text(0.3551822503961965, 0.6964285714285714, 'X[5] <= 85553.031\ngini = 0.044\nsamples = 660\nvalue = [413.917, 9.635]'),
#  Text(0.35264659270998416, 0.6607142857142857, 'X[4] <= 0.5\ngini = 0.013\nsamples = 574\nvalue = [361.547, 2.409]'),
#  Text(0.35163232963549923, 0.625, 'X[0] <= 730.5\ngini = 0.269\nsamples = 21\nvalue = [12.619, 2.409]'),
#  Text(0.35061806656101424, 0.5892857142857143, 'gini = 0.0\nsamples = 19\nvalue = [11.988, 0.0]'),
#  Text(0.35264659270998416, 0.5892857142857143, 'X[9] <= 110630.863\ngini = 0.329\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.35163232963549923, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.3536608557844691, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.3536608557844691, 0.625, 'gini = 0.0\nsamples = 553\nvalue = [348.927, 0.0]'),
#  Text(0.3577179080824089, 0.6607142857142857, 'X[5] <= 87623.469\ngini = 0.213\nsamples = 86\nvalue = [52.371, 7.226]'),
#  Text(0.35568938193343896, 0.625, 'X[3] <= 29.5\ngini = 0.451\nsamples = 6\nvalue = [2.524, 4.818]'),
#  Text(0.35467511885895403, 0.5892857142857143, 'gini = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.35670364500792395, 0.5892857142857143, 'X[8] <= 0.5\ngini = 0.205\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.35568938193343896, 0.5535714285714286, 'X[0] <= 665.5\ngini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.35467511885895403, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.35670364500792395, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.3577179080824089, 0.5535714285714286, 'gini = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.35974643423137875, 0.625, 'X[3] <= 36.5\ngini = 0.088\nsamples = 80\nvalue = [49.847, 2.409]'),
#  Text(0.3587321711568938, 0.5892857142857143, 'gini = 0.0\nsamples = 57\nvalue = [35.965, 0.0]'),
#  Text(0.3607606973058637, 0.5892857142857143, 'X[0] <= 623.5\ngini = 0.252\nsamples = 23\nvalue = [13.881, 2.409]'),
#  Text(0.35974643423137875, 0.5535714285714286, 'X[0] <= 609.5\ngini = 0.475\nsamples = 7\nvalue = [3.786, 2.409]'),
#  Text(0.3587321711568938, 0.5178571428571429, 'gini = 0.0\nsamples = 6\nvalue = [3.786, 0.0]'),
#  Text(0.3607606973058637, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.3617749603803487, 0.5535714285714286, 'gini = 0.0\nsamples = 16\nvalue = [10.096, 0.0]'),
#  Text(0.3655784469096672, 0.6964285714285714, 'X[0] <= 780.5\ngini = 0.211\nsamples = 87\nvalue = [53.002, 7.226]'),
#  Text(0.3627892234548336, 0.6607142857142857, 'X[4] <= 4.0\ngini = 0.329\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.3617749603803487, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.36380348652931854, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.3683676703645008, 0.6607142857142857, 'X[9] <= 193475.305\ngini = 0.154\nsamples = 85\nvalue = [52.371, 4.818]'),
#  Text(0.3658320126782884, 0.625, 'X[3] <= 37.5\ngini = 0.091\nsamples = 77\nvalue = [47.954, 2.409]'),
#  Text(0.3648177496038035, 0.5892857142857143, 'gini = -0.0\nsamples = 67\nvalue = [42.275, 0.0]'),
#  Text(0.3668462757527734, 0.5892857142857143, 'X[4] <= 7.5\ngini = 0.418\nsamples = 10\nvalue = [5.679, 2.409]'),
#  Text(0.3648177496038035, 0.5535714285714286, 'X[7] <= 0.5\ngini = 0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  Text(0.36380348652931854, 0.5178571428571429, 'gini = 0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.3658320126782884, 0.5178571428571429, 'gini = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.36887480190174327, 0.5535714285714286, 'X[4] <= 8.5\ngini = 0.451\nsamples = 3\nvalue = [1.262, 2.409]'),
#  Text(0.36786053882725833, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.3698890649762282, 0.5178571428571429, 'gini = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.37090332805071313, 0.625, 'X[9] <= 194031.461\ngini = 0.457\nsamples = 8\nvalue = [4.417, 2.409]'),
#  Text(0.3698890649762282, 0.5892857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.3719175911251981, 0.5892857142857143, 'X[0] <= 814.5\ngini = 0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  Text(0.37090332805071313, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.37293185419968305, 0.5535714285714286, 'gini = 0.0\nsamples = 6\nvalue = [3.786, 0.0]'),
#  Text(0.39486925515055465, 0.8392857142857143, 'X[5] <= 110932.539\ngini = 0.393\nsamples = 559\nvalue = [321.796, 118.032]'),
#  Text(0.3734389857369255, 0.8035714285714286, 'X[7] <= 0.5\ngini = 0.484\nsamples = 33\nvalue = [15.143, 21.679]'),
#  Text(0.37090332805071313, 0.7678571428571429, 'X[0] <= 681.5\ngini = 0.329\nsamples = 8\nvalue = [2.524, 9.635]'),
#  Text(0.3698890649762282, 0.7321428571428571, 'gini = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.3719175911251981, 0.7321428571428571, 'X[9] <= 20385.635\ngini = 0.5\nsamples = 5\nvalue = [2.524, 2.409]'),
#  Text(0.37090332805071313, 0.6964285714285714, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.37293185419968305, 0.6964285714285714, 'gini = -0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.37597464342313786, 0.7678571428571429, 'X[9] <= 58364.375\ngini = 0.5\nsamples = 25\nvalue = [12.619, 12.044]'),
#  Text(0.3749603803486529, 0.7321428571428571, 'gini = 0.0\nsamples = 9\nvalue = [5.679, 0.0]'),
#  Text(0.37698890649762284, 0.7321428571428571, 'X[0] <= 660.5\ngini = 0.464\nsamples = 16\nvalue = [6.941, 12.044]'),
#  Text(0.3749603803486529, 0.6964285714285714, 'X[4] <= 1.0\ngini = 0.437\nsamples = 9\nvalue = [5.048, 2.409]'),
#  Text(0.373946117274168, 0.6607142857142857, 'X[5] <= 109265.105\ngini = 0.329\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.37293185419968305, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.3749603803486529, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.37597464342313786, 0.6607142857142857, 'gini = -0.0\nsamples = 7\nvalue = [4.417, 0.0]'),
#  Text(0.3790174326465927, 0.6964285714285714, 'X[3] <= 37.5\ngini = 0.274\nsamples = 7\nvalue = [1.893, 9.635]'),
#  Text(0.3780031695721078, 0.6607142857142857, 'X[0] <= 790.0\ngini = 0.205\nsamples = 6\nvalue = [1.262, 9.635]'),
#  Text(0.37698890649762284, 0.625, 'X[9] <= 178168.32\ngini = 0.115\nsamples = 5\nvalue = [0.631, 9.635]'),
#  Text(0.37597464342313786, 0.5892857142857143, 'gini = 0.0\nsamples = 4\nvalue = [0.0, 9.635]'),
#  Text(0.3780031695721078, 0.5892857142857143, 'gini = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.3790174326465927, 0.625, 'gini = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.38003169572107764, 0.6607142857142857, 'gini = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.41629952456418384, 0.8035714285714286, 'X[5] <= 205016.172\ngini = 0.364\nsamples = 526\nvalue = [306.652, 96.352]'),
#  Text(0.40153724247226624, 0.7678571428571429, 'X[2] <= 0.5\ngini = 0.35\nsamples = 521\nvalue = [305.39, 89.126]'),
#  Text(0.3894136291600634, 0.7321428571428571, 'X[5] <= 143855.531\ngini = 0.251\nsamples = 300\nvalue = [181.089, 31.315]'),
#  Text(0.3845958795562599, 0.6964285714285714, 'X[3] <= 36.5\ngini = 0.146\nsamples = 182\nvalue = [112.313, 9.635]'),
#  Text(0.38206022187004757, 0.6607142857142857, 'X[0] <= 519.0\ngini = 0.054\nsamples = 134\nvalue = [83.919, 2.409]'),
#  Text(0.3810459587955626, 0.625, 'X[0] <= 509.0\ngini = 0.437\nsamples = 9\nvalue = [5.048, 2.409]'),
#  Text(0.38003169572107764, 0.5892857142857143, 'gini = -0.0\nsamples = 8\nvalue = [5.048, 0.0]'),
#  Text(0.38206022187004757, 0.5892857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.3830744849445325, 0.625, 'gini = 0.0\nsamples = 125\nvalue = [78.871, 0.0]'),
#  Text(0.3871315372424723, 0.6607142857142857, 'X[3] <= 37.5\ngini = 0.323\nsamples = 48\nvalue = [28.394, 7.226]'),
#  Text(0.3861172741679873, 0.625, 'X[9] <= 156743.602\ngini = 0.475\nsamples = 21\nvalue = [11.357, 7.226]'),
#  Text(0.38408874801901743, 0.5892857142857143, 'X[5] <= 138384.523\ngini = 0.493\nsamples = 12\nvalue = [5.679, 7.226]'),
#  Text(0.3830744849445325, 0.5535714285714286, 'X[5] <= 121391.016\ngini = 0.423\nsamples = 8\nvalue = [3.155, 7.226]'),
#  Text(0.38206022187004757, 0.5178571428571429, 'gini = 0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.38408874801901743, 0.5178571428571429, 'X[5] <= 129168.309\ngini = 0.329\nsamples = 6\nvalue = [1.893, 7.226]'),
#  Text(0.3830744849445325, 0.48214285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.38510301109350237, 0.48214285714285715, 'X[9] <= 133174.609\ngini = 0.493\nsamples = 4\nvalue = [1.893, 2.409]'),
#  Text(0.38408874801901743, 0.44642857142857145, 'gini = -0.0\nsamples = 3\nvalue = [1.893, 0.0]'),
#  Text(0.3861172741679873, 0.44642857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.38510301109350237, 0.5535714285714286, 'gini = 0.0\nsamples = 4\nvalue = [2.524, 0.0]'),
#  Text(0.3881458003169572, 0.5892857142857143, 'X[5] <= 116435.289\ngini = 0.0\nsamples = 9\nvalue = [5.679, 0.0]'),
#  Text(0.3871315372424723, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.38916006339144216, 0.5535714285714286, 'gini = 0.0\nsamples = 8\nvalue = [5.048, 0.0]'),
#  Text(0.3881458003169572, 0.625, 'gini = -0.0\nsamples = 27\nvalue = [17.036, 0.0]'),
#  Text(0.3942313787638669, 0.6964285714285714, 'X[5] <= 144394.617\ngini = 0.364\nsamples = 118\nvalue = [68.776, 21.679]'),
#  Text(0.39321711568938195, 0.6607142857142857, 'gini = 0.0\nsamples = 3\nvalue = [0.0, 7.226]'),
#  Text(0.3952456418383518, 0.6607142857142857, 'X[9] <= 101773.469\ngini = 0.287\nsamples = 115\nvalue = [68.776, 14.453]'),
#  Text(0.3942313787638669, 0.625, 'X[5] <= 146487.055\ngini = 0.418\nsamples = 60\nvalue = [34.072, 14.453]'),
#  Text(0.392202852614897, 0.5892857142857143, 'X[7] <= 0.5\ngini = 0.205\nsamples = 3\nvalue = [0.631, 4.818]'),
#  Text(0.391188589540412, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.39321711568938195, 0.5535714285714286, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.39625990491283675, 0.5892857142857143, 'X[9] <= 101287.082\ngini = 0.347\nsamples = 57\nvalue = [33.441, 9.635]'),
#  Text(0.3952456418383518, 0.5535714285714286, 'X[1] <= 0.5\ngini = 0.292\nsamples = 56\nvalue = [33.441, 7.226]'),
#  Text(0.3942313787638669, 0.5178571428571429, 'X[9] <= 44141.336\ngini = 0.486\nsamples = 19\nvalue = [10.096, 7.226]'),
#  Text(0.392202852614897, 0.48214285714285715, 'X[0] <= 654.0\ngini = 0.384\nsamples = 7\nvalue = [2.524, 7.226]'),
#  Text(0.391188589540412, 0.44642857142857145, 'X[4] <= 8.0\ngini = 0.253\nsamples = 5\nvalue = [1.262, 7.226]'),
#  Text(0.3901743264659271, 0.4107142857142857, 'X[5] <= 158021.891\ngini = 0.148\nsamples = 4\nvalue = [0.631, 7.226]'),
#  Text(0.38916006339144216, 0.375, 'X[0] <= 534.0\ngini = 0.329\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.3881458003169572, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.3901743264659271, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.391188589540412, 0.375, 'gini = -0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.392202852614897, 0.4107142857142857, 'gini = -0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.39321711568938195, 0.44642857142857145, 'gini = -0.0\nsamples = 2\nvalue = [1.262, 0.0]'),
#  Text(0.39625990491283675, 0.48214285714285715, 'X[0] <= 621.5\ngini = 0.0\nsamples = 12\nvalue = [7.572, 0.0]'),
#  Text(0.3952456418383518, 0.44642857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.39727416798732174, 0.44642857142857145, 'gini = 0.0\nsamples = 11\nvalue = [6.941, 0.0]'),
#  Text(0.39625990491283675, 0.5178571428571429, 'gini = -0.0\nsamples = 37\nvalue = [23.346, 0.0]'),
#  Text(0.39727416798732174, 0.5535714285714286, 'gini = -0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.39625990491283675, 0.625, 'gini = 0.0\nsamples = 55\nvalue = [34.703, 0.0]'),
#  Text(0.4136608557844691, 0.7321428571428571, 'X[3] <= 31.5\ngini = 0.433\nsamples = 221\nvalue = [124.301, 57.811]'),
#  Text(0.40031695721077654, 0.6964285714285714, 'X[1] <= 1.5\ngini = 0.23\nsamples = 78\nvalue = [47.323, 7.226]'),
#  Text(0.3993026941362916, 0.6607142857142857, 'gini = -0.0\nsamples = 64\nvalue = [40.382, 0.0]'),
#  Text(0.40133122028526147, 0.6607142857142857, 'X[0] <= 600.0\ngini = 0.5\nsamples = 14\nvalue = [6.941, 7.226]'),
#  Text(0.40031695721077654, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  Text(0.40234548335974646, 0.625, 'X[9] <= 142878.844\ngini = 0.383\nsamples = 12\nvalue = [6.941, 2.409]'),
#  Text(0.40031695721077654, 0.5892857142857143, 'X[3] <= 21.5\ngini = 0.0\nsamples = 10\nvalue = [6.31, 0.0]'),
#  Text(0.3993026941362916, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.40133122028526147, 0.5535714285714286, 'gini = 0.0\nsamples = 9\nvalue = [5.679, 0.0]'),
#  Text(0.4043740095087163, 0.5892857142857143, 'X[3] <= 27.5\ngini = 0.329\nsamples = 2\nvalue = [0.631, 2.409]'),
#  Text(0.4033597464342314, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 2.409]'),
#  Text(0.40538827258320126, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0.631, 0.0]'),
#  Text(0.42700475435816165, 0.6964285714285714, 'X[9] <= 177037.523\ngini = 0.479\nsamples = 143\nvalue = [76.979, 50.585]'),
#  Text(0.4259904912836767, 0.6607142857142857, 'X[9] <= 172711.055\ngini = 0.492\nsamples = 124\nvalue = [64.99, 50.585]'),
#  Text(0.41920760697305864, 0.625, 'X[5] <= 134547.008\ngini = 0.476\nsamples = 118\nvalue = [63.728, 40.95]'),
#  Text(0.41172741679873215, 0.5892857142857143, 'X[5] <= 123106.504\ngini = 0.499\nsamples = 64\nvalue = [31.549, 33.723]'),
#  Text(0.4074167987321712, 0.5535714285714286, 'X[0] <= 564.0\ngini = 0.33\nsamples = 31\nvalue = [18.298, 4.818]'),
#  Text(0.40538827258320126, 0.5178571428571429, 'X[5] <= 119629.379\ngini = 0.451\nsamples = 6\nvalue = [2.524, 4.818]'),
#  Text(0.4043740095087163, 0.48214285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 4.818]'),
#  ...]

# %% [markdown]
# # 衡量模型

# %%
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
ori_predictions = ori_clf.predict(x_test) #用決策樹預測測試資料
ori_scores = cross_val_score(ori_clf,x_test,y_test, cv=10) #10-fold cross validation score
print("%0.3f accuracy with a standard deviation of %0.3f" % (ori_scores.mean(), ori_scores.std()))
# Out:
# 0.79 accuracy with a standard deviation of 0.02

# %%
ori_cm = confusion_matrix(y_test,ori_predictions, labels=ori_clf.classes_) #混淆矩陣
ori_disp = ConfusionMatrixDisplay(confusion_matrix=ori_cm, display_labels=ori_clf.classes_)
ori_disp.plot()

plt.show()

# %%
ori_accuracy = (ori_cm[0,0]+ori_cm[1,1])/3000
ori_recall = ori_cm[1,1]/(ori_cm[1,0]+ori_cm[1,1]) #計算recall
ori_precision = ori_cm[1,1]/(ori_cm[1,1]+ori_cm[0,1]) #計算precision
ori_F1 = 2 * (ori_precision * ori_recall) / (ori_precision + ori_recall) #計算F1
print("Accuracy: \t%0.3f" % (ori_accuracy))
print("Precision: \t%0.3f" % (ori_precision))
print("Recall: \t%0.3f" % (ori_recall))
print("F1 score: \t%0.3f" % (ori_F1))
# Out:
# Accuracy: 	0.799
# Precision: 	0.485
# Recall: 	0.502
# F1 score: 	0.493

# %%
import graphviz 
ori_dot_data2 = tree.export_graphviz(ori_clf, out_file=None, 
                     feature_names=feature_cols,  
                     class_names=['0','1'],  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(ori_dot_data2)  
graph.render("ori_tree_gini")
# Out:
# 'ori_tree_gini.pdf'

# %% [markdown]
# # 設置max_leaf_nodes

# %%
for i in range (2,20) :
    test_my_clf = tree.DecisionTreeClassifier(splitter = "best",max_leaf_nodes= i)
    test_my_clf =  test_my_clf.fit(x_train,y_train)
    test_my_clf.score(x_test,y_test)
    scores = cross_val_score(test_my_clf,x_test,y_test, cv=10)
    predictions = test_my_clf.predict(x_test)
    cm = confusion_matrix(y_test, predictions, labels=test_my_clf.classes_)
    accuracy = (cm[0,0]+cm[1,1])/3000
    recall = cm[1,1]/(cm[1,0]+cm[1,1]) #計算recall
    precision = cm[1,1]/(cm[1,1]+cm[0,1]) #計算precision
    F1 = 2 * (precision * recall) / (precision + recall) #計算F1
    print("Accuracy: \t%0.3f" % (accuracy))
    print("Precision: \t%0.3f" % (precision))
    print("Recall: \t%0.3f" % (recall))
    print("F1 score: \t%0.3f" % (F1))
    print("%0.3f accuracy with a standard deviation of %0.3f, max_leaf_nodes = %i" % (scores.mean(), scores.std(),i))
    print("---------------------")
# Out:
# C:\Users\annie\AppData\Local\Temp\ipykernel_25948\4105592533.py:10: RuntimeWarning: invalid value encountered in longlong_scalars
#   precision = cm[1,1]/(cm[1,1]+cm[0,1]) #計算precision
# Accuracy: 	0.805
# Precision: 	nan
# Recall: 	0.000
# F1 score: 	nan
# 0.805 accuracy with a standard deviation of 0.002, max_leaf_nodes = 2
# ---------------------
# Accuracy: 	0.838
# Precision: 	0.668
# Recall: 	0.330
# F1 score: 	0.442
# 0.832 accuracy with a standard deviation of 0.013, max_leaf_nodes = 3
# ---------------------
# Accuracy: 	0.846
# Precision: 	0.679
# Recall: 	0.396
# F1 score: 	0.500
# 0.836 accuracy with a standard deviation of 0.010, max_leaf_nodes = 4
# ---------------------
# Accuracy: 	0.846
# Precision: 	0.679
# Recall: 	0.396
# F1 score: 	0.500
# 0.844 accuracy with a standard deviation of 0.009, max_leaf_nodes = 5
# ---------------------
# Accuracy: 	0.850
# Precision: 	0.685
# Recall: 	0.421
# F1 score: 	0.522
# 0.844 accuracy with a standard deviation of 0.009, max_leaf_nodes = 6
# ---------------------
# Accuracy: 	0.850
# Precision: 	0.685
# Recall: 	0.421
# F1 score: 	0.522
# 0.848 accuracy with a standard deviation of 0.007, max_leaf_nodes = 7
# ---------------------
# Accuracy: 	0.850
# Precision: 	0.685
# Recall: 	0.421
# F1 score: 	0.522
# 0.848 accuracy with a standard deviation of 0.007, max_leaf_nodes = 8
# ---------------------
# Accuracy: 	0.850
# Precision: 	0.685
# Recall: 	0.421
# F1 score: 	0.522
# 0.854 accuracy with a standard deviation of 0.007, max_leaf_nodes = 9
# ---------------------
# Accuracy: 	0.850
# Precision: 	0.685
# Recall: 	0.421
# F1 score: 	0.522
# 0.859 accuracy with a standard deviation of 0.009, max_leaf_nodes = 10
# ---------------------
# Accuracy: 	0.856
# Precision: 	0.767
# Recall: 	0.372
# F1 score: 	0.501
# 0.859 accuracy with a standard deviation of 0.009, max_leaf_nodes = 11
# ---------------------
# Accuracy: 	0.861
# Precision: 	0.780
# Recall: 	0.401
# F1 score: 	0.529
# 0.859 accuracy with a standard deviation of 0.010, max_leaf_nodes = 12
# ---------------------
# Accuracy: 	0.861
# Precision: 	0.780
# Recall: 	0.401
# F1 score: 	0.529
# 0.862 accuracy with a standard deviation of 0.008, max_leaf_nodes = 13
# ---------------------
# Accuracy: 	0.861
# Precision: 	0.780
# Recall: 	0.401
# F1 score: 	0.529
# 0.862 accuracy with a standard deviation of 0.008, max_leaf_nodes = 14
# ---------------------
# Accuracy: 	0.861
# Precision: 	0.780
# Recall: 	0.401
# F1 score: 	0.529
# 0.862 accuracy with a standard deviation of 0.007, max_leaf_nodes = 15
# ---------------------
# Accuracy: 	0.861
# Precision: 	0.780
# Recall: 	0.401
# F1 score: 	0.529
# 0.864 accuracy with a standard deviation of 0.010, max_leaf_nodes = 16
# ---------------------
# Accuracy: 	0.861
# Precision: 	0.780
# Recall: 	0.401
# F1 score: 	0.529
# 0.863 accuracy with a standard deviation of 0.008, max_leaf_nodes = 17
# ---------------------
# Accuracy: 	0.861
# Precision: 	0.780
# Recall: 	0.401
# F1 score: 	0.529
# 0.863 accuracy with a standard deviation of 0.007, max_leaf_nodes = 18
# ---------------------
# Accuracy: 	0.861
# Precision: 	0.780
# Recall: 	0.401
# F1 score: 	0.529
# 0.864 accuracy with a standard deviation of 0.010, max_leaf_nodes = 19
# ---------------------

# %%
my_clf = tree.DecisionTreeClassifier(splitter = "best",max_leaf_nodes = 12)
my_clf = my_clf.fit(x_train,y_train)
scores = cross_val_score(my_clf,x_test,y_test, cv=10)

# %%
tree.plot_tree(my_clf)
# Out:
# [Text(0.4666666666666667, 0.9166666666666666, 'X[3] <= 44.5\ngini = 0.329\nsamples = 7000\nvalue = [5547, 1453]'),
#  Text(0.26666666666666666, 0.75, 'X[6] <= 2.5\ngini = 0.23\nsamples = 5355\nvalue = [4645, 710]'),
#  Text(0.2, 0.5833333333333334, 'X[6] <= 1.5\ngini = 0.205\nsamples = 5222\nvalue = [4617, 605]'),
#  Text(0.13333333333333333, 0.4166666666666667, 'X[3] <= 38.5\ngini = 0.301\nsamples = 2603\nvalue = [2123, 480]'),
#  Text(0.06666666666666667, 0.25, 'gini = 0.232\nsamples = 1869\nvalue = [1619, 250]'),
#  Text(0.2, 0.25, 'gini = 0.43\nsamples = 734\nvalue = [504, 230]'),
#  Text(0.26666666666666666, 0.4166666666666667, 'gini = 0.091\nsamples = 2619\nvalue = [2494, 125]'),
#  Text(0.3333333333333333, 0.5833333333333334, 'gini = 0.332\nsamples = 133\nvalue = [28, 105]'),
#  Text(0.6666666666666666, 0.75, 'X[8] <= 0.5\ngini = 0.495\nsamples = 1645\nvalue = [902, 743]'),
#  Text(0.4666666666666667, 0.5833333333333334, 'X[3] <= 51.5\ngini = 0.44\nsamples = 713\nvalue = [233, 480]'),
#  Text(0.4, 0.4166666666666667, 'X[6] <= 1.5\ngini = 0.494\nsamples = 442\nvalue = [197, 245]'),
#  Text(0.3333333333333333, 0.25, 'gini = 0.453\nsamples = 283\nvalue = [98, 185]'),
#  Text(0.4666666666666667, 0.25, 'X[6] <= 2.5\ngini = 0.47\nsamples = 159\nvalue = [99, 60]'),
#  Text(0.4, 0.08333333333333333, 'gini = 0.381\nsamples = 133\nvalue = [99, 34]'),
#  Text(0.5333333333333333, 0.08333333333333333, 'gini = 0.0\nsamples = 26\nvalue = [0, 26]'),
#  Text(0.5333333333333333, 0.4166666666666667, 'gini = 0.23\nsamples = 271\nvalue = [36, 235]'),
#  Text(0.8666666666666667, 0.5833333333333334, 'X[6] <= 2.5\ngini = 0.405\nsamples = 932\nvalue = [669, 263]'),
#  Text(0.8, 0.4166666666666667, 'X[6] <= 1.5\ngini = 0.374\nsamples = 889\nvalue = [668, 221]'),
#  Text(0.7333333333333333, 0.25, 'X[3] <= 57.5\ngini = 0.449\nsamples = 512\nvalue = [338, 174]'),
#  Text(0.6666666666666666, 0.08333333333333333, 'gini = 0.494\nsamples = 314\nvalue = [174, 140]'),
#  Text(0.8, 0.08333333333333333, 'gini = 0.284\nsamples = 198\nvalue = [164, 34]'),
#  Text(0.8666666666666667, 0.25, 'gini = 0.218\nsamples = 377\nvalue = [330, 47]'),
#  Text(0.9333333333333333, 0.4166666666666667, 'gini = 0.045\nsamples = 43\nvalue = [1, 42]')]

# %% [markdown]
# # 衡量新樹

# %%
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(my_clf,x_test,y_test, cv=10)
print("%0.3f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# 0.859 accuracy with a standard deviation of 0.01

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
predictions = my_clf.predict(x_test)
cm = confusion_matrix(y_test, predictions, labels=my_clf.classes_)
disp = ConfusionMatrixDisplay( confusion_matrix=cm , display_labels=my_clf.classes_)
disp.plot()

plt.show()

# %%
accuracy = (cm[0,0]+cm[1,1])/3000
recall = cm[1,1]/(cm[1,0]+cm[1,1]) #計算recall
precision = cm[1,1]/(cm[1,1]+cm[0,1]) #計算precision
F1 = 2 * (precision * recall) / (precision + recall) #計算F1
print("Accuracy: \t%0.3f" % (accuracy))
print("Precision: \t%0.3f" % (precision))
print("Recall: \t%0.3f" % (recall))
print("F1 score: \t%0.3f" % (F1))
# Out:
# Accuracy: 	0.861
# Precision: 	0.780
# Recall: 	0.401
# F1 score: 	0.529

# %%
import graphviz 
dot_data = tree.export_graphviz(my_clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("my_tree_gini")
# Out:
# 'my_tree_gini.pdf'

# %%
dot_data2 = tree.export_graphviz(my_clf, out_file=None, 
                     feature_names=feature_cols,  
                     class_names=['0','1'],  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data2)  
graph.render("my_tree2_gini")
# Out:
# 'my_tree2_gini.pdf'
